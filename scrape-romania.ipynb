# %%
from util.spider import Spider
import pandas as pd

# %%
attrs = {
        'name':         'name',
        'ingredients':  'recipeIngredient',
        'total_time':   'totalTime',
        'instructions': 'recipeInstructions',
        'servings':     'recipeYield',
        'category':     'recipeCategory',
        'prep_time':    'prepTime',
        'cook_time':    'cookTime',
}
available_json = {'xpath' : "normalize-space(//script[@type='application/ld+json'][contains(text(), 'recipeIngredient')])"}
listing={'items': '//div[@class="postInfo"]/a/@href', 'next': { 'next_page_str': '/page/{}', 'type': 'url'}}
seeds = [
        'https://www.lauralaurentiu.ro/retete-culinare/supe-ciorbe', 

        'https://www.lauralaurentiu.ro/retete-culinare/retete-de-salate', 

        'https://www.lauralaurentiu.ro/retete-culinare/retete-cu-paste',


        'https://www.lauralaurentiu.ro/retete-culinare/peste-fructe-de-mare',
        
        'https://www.lauralaurentiu.ro/retete-culinare/aperitive',


        'https://www.lauralaurentiu.ro/tag/retete-cu-carne',
        'https://www.lauralaurentiu.ro/tag/fara-carne',
        
        
        ]

# %%
custom_header_template = { #setup custom header because this website requires certain headers
        'referer': 'https://www.lauralaurentiu.ro/retete-culinare/supe-ciorbe/ramen-cu-miso-reteta-video-de-supa-ramen-japoneza.html',
        'Accept-Language': '*',
        'Accept-Encoding': '*', #accept encoding for this website has to be *
        'sec-ch-ua': '" Not A;Brand";v="99", "Chromium";v="100", "Google Chrome";v="100"',
        'sec-fetch-site' : 'same-origin',
        'cookie': '_ga=GA1.2.1978438003.1649681893; cb-enabled=enabled; _gid=GA1.2.1870821735.1650271735; ao-fpgad=%7B%22fpcRequired%22%3Afalse%2C%22checkTS%22%3A1650271735392%2C%22domain%22%3A%22lauralaurentiu.ro%22%7D; __gads=ID=3dd1ab9c6ddf9fc9-2289c17b2ed20094:T=1649681893:RT=1650271783:S=ALNI_MbZpRpmkjwza5LhQQ1HkGR0H4wMjQ',
        'user-agent': ''}

# %%
laural_spider = Spider('https://www.lauralaurentiu.ro', seeds, listing,attrs, available_json=available_json,header=custom_header_template)

# %%
laural_spider.scrape_one_item('https://www.lauralaurentiu.ro/retete-culinare/supe-ciorbe/ramen-cu-miso-reteta-video-de-supa-ramen-japoneza.html')
# Out:
# {'name': 'Ramen cu miso &#8211; rețetă video de supă ramen japoneză',
#  'total_time': 'PT02H15M',
#  'ingredients': ['1 kg. de oase de porc (oase garf am folosit eu)',
#   '800 de grame de oase de pui (spate și gheare, gâturi etc)',
#   '1 bucată de ghimbir de 5-6 cm',
#   '2-3 căței de usturoi',
#   '2 legături mari de ceapă verde',
#   '2-3 litri de apă proaspătă',
#   '100 de grame de pastă miso roșie (asta am folosit eu, se poate folosi și miso alb)',
#   '1 linguriță cu vârf (sau mai mult) de pastă picantă doubanjiang',
#   '1-2 linguri de ulei de susan',
#   '2 linguri cu vârf de semințe de susan ușor prăjite',
#   '2 căței mari de usturoi, răzuiți fin (pe răzătoarea cu găuri mici)',
#   '3 cm. ghimbir proaspăt, răzuit fin',
#   '1 șalotă (40 de grame) fin tocată',
#   '250 de grame de carne de porc tocată',
#   '2-3 linguri de zahăr (eu l-am înlocuit cu 150 ml. de mirin - vin\xa0japonez dulce, special pt. gătit)',
#   'sare după gust',
#   '½ de linguriță de piper alb (sau mai puțin, dacă nu vă place prea picant)',
#   'câte 75 de grame de tăieței pentru ramen (uscați) pentru fiecare porție',
#   'toppingurile pentru ramen preferate, despre care am scris în detaliu, mai jos',
#   'toppingurile pentru ramen preferate, despre care am scris în detaliu, mai jos'],
#  'instructions': ['Advertising Nu cu foarte mult timp în urmă, vă povesteam că abia la trei ani de la primul contact mai &hellip;'],
#  'servings': '4 portii',
#  'category': ['supe si ciorbe'],
#  'prep_time': 'PT00H30M',
#  'cook_time': 'PT01H45M'}

# %%
result_list = laural_spider.start_scrape(multithread=False)
# Out:
# spider is scraping page: 1
# spider is scraping page: 2
# spider is scraping page: 3
# spider is scraping page: 4
# spider is scraping page: 5
# spider is scraping page: 6
# spider is scraping page: 7
# spider is scraping page: 1
# spider is scraping page: 2
# spider is scraping page: 3
# spider is scraping page: 4
# spider is scraping page: 5
# spider is scraping page: 6
# spider is scraping page: 7
# spider is scraping page: 1
# spider is scraping page: 2
# spider is scraping page: 3
# spider is scraping page: 4
# spider is scraping page: 5
# spider is scraping page: 1
# spider is scraping page: 2
# spider is scraping page: 3
# spider is scraping page: 4
# spider is scraping page: 5
# spider is scraping page: 6
# spider is scraping page: 1
# spider is scraping page: 2
# spider is scraping page: 3
# spider is scraping page: 4
# spider is scraping page: 5
# spider is scraping page: 6
# spider is scraping page: 7
# spider is scraping page: 8
# spider is scraping page: 9
# spider is scraping page: 1
# spider is scraping page: 2
# json loads does not work
# Expecting value: line 1 column 1 (char 0)
# cannot decode json
# No value to decode
# local variable 'script_data' referenced before assignment
# something is wrong for item: https://www.lauralaurentiu.ro/retete-culinare/ce-au-in-comun-pulpa-de-rata-avocado-fructele-si-gorgonzola.html
# json loads does not work
# Expecting value: line 1 column 1 (char 0)
# cannot decode json
# No value to decode
# local variable 'script_data' referenced before assignment
# something is wrong for item: https://www.lauralaurentiu.ro/retete-culinare/meniu-cu-un-numitor-comun-bulete-muschiulet-si-millefeuille-si-un-concurs-pentru-voi.html
# spider is scraping page: 3
# json loads does not work
# Expecting value: line 1 column 1 (char 0)
# cannot decode json
# No value to decode
# local variable 'script_data' referenced before assignment
# something is wrong for item: https://www.lauralaurentiu.ro/diverse/articole/ce-am-gatit-eu-pentru-concursul-arena-bloggerilor.html
# spider is scraping page: 4
# spider is scraping page: 5
# spider is scraping page: 6
# spider is scraping page: 7
# spider is scraping page: 8
# spider is scraping page: 9
# spider is scraping page: 10
# spider is scraping page: 11
# spider is scraping page: 12
# spider is scraping page: 13
# spider is scraping page: 14
# spider is scraping page: 1
# spider is scraping page: 2
# json loads does not work
# Expecting value: line 1 column 1 (char 0)
# cannot decode json
# No value to decode
# local variable 'script_data' referenced before assignment
# something is wrong for item: https://www.lauralaurentiu.ro/retete-culinare/ciuperci-umplute-la-cuptor-de-post.html
# spider is scraping page: 3
# spider is scraping page: 4
# spider is scraping page: 5
# json loads does not work
# Expecting value: line 1 column 1 (char 0)
# cannot decode json
# No value to decode
# local variable 'script_data' referenced before assignment
# something is wrong for item: https://www.lauralaurentiu.ro/diverse/oaspeti-in-bucatarie-mirela-ivascu-retete-pentru-un-craciun-fara-carne.html
# spider is scraping page: 6
# spider is scraping page: 7
# spider is scraping page: 8
# spider is scraping page: 9
# spider is scraping page: 10
# spider is scraping page: 11
# spider is scraping page: 12

# %%
result_df = pd.DataFrame(result_list)

# %%
result_df
# Out:
#                                                   name total_time  \
# 0    Ciorbă de miel a la grec &#8211; rețeta grecea...   PT02H25M
# 1    Supă cremă de cartofi cu praz &#8211; rețeta d...   PT00H30M
# 2    Ciorbă de cartofi cu tarhon &#8211; rețetă de ...   PT00H30M
# 3    Supă cremă de spanac cu crutoane de casă cu pa...   PT00H35M
# 4                    Supă de gulii cu găluște de făină   PT00H35M
# ..                                                 ...        ...
# 580                                   Placinta intinsa   PT01H40M
# 581                  Bomboane fondante &#8211; de post   PT01H10M
# 582                       Mâncare de mazăre cu morcovi   PT00H40M
# 583  Vol-au-vent &#8211; pateuri usoare ca pana din...   PT02H50M
# 584                      Mucenici tradiționali de post   PT02H40M
#
#                                            ingredients  \
# 0    [1,2 - 1,5 carne de miel cu os (cap, gât, coad...
# 1    [250 grame praz, doar partea albă și cea verde...
# 2    [1 kg de cartofi recomandați pentru salată și ...
# 3    [500 de grame de spanac proaspăt sau 200 de gr...
# 4    [2 gulii mărișoare (cam de 180-200 de grame/bu...
# ..                                                 ...
# 580  [800 de grame de faina cernuta, 500 ml de apa,...
# 581  [500 de grame de zahar, zeama de la 1/2 de lam...
# 582  [500 de grame de mazăre boabe, proaspătă sau c...
# 583  [400 de grame de aluat foietaj clasic (click p...
# 584  [1 kg de faina, 140 de ml ulei, 200 de grame d...
#
#                                           instructions      servings  \
# 0    [Advertising Ciorbă de miel a la grec &#8211; ...      8 portii
# 1    [Advertising Supă cremă de cartofi cu praz &#8...      4 portii
# 2    [Advertising Cea mai simplă și rapidă ciorbă d...      8 portii
# 3    [Advertising Aproape de necrezut că din ingred...      4 portii
# 4    [Advertising Supă de gulii cu găluște de făină...     10 portii
# ..                                                 ...           ...
# 580  [Advertising Placinta intinsa este un desert p...     12 portii
# 581  [Advertising Am citit pe culinar.ro o reteta p...     12 portii
# 582  [Advertising Zilele în care avem în meniu o mâ...      6 portii
# 583  [Advertising Vol au vent, pateuri fine si usoa...  12-16 portii
# 584  [Advertising Mucenici tradiționali de post, re...     40 portii
#
#                             category prep_time cook_time
# 0                   [supe si ciorbe]  PT00H25M  PT02H00M
# 1                   [supe si ciorbe]  PT00H05M  PT00H25M
# 2                   [supe si ciorbe]  PT00H05M  PT00H28M
# 3                   [supe si ciorbe]  PT00H10M  PT00H25M
# 4                   [supe si ciorbe]  PT00H10M  PT00H25M
# ..                               ...       ...       ...
# 580                      [patiserie]  PT01H00M  PT00H40M
# 581  [deserturi si dulciuri de casa]  PT01H00M  PT00H10M
# 582            [retete de garnitura]  PT00H15M  PT00H25M
# 583                      [patiserie]  PT02H30M  PT00H20M
# 584            [retete traditionale]  PT02H00M  PT00H40M
#
# [585 rows x 8 columns]

# %%
result_df.to_csv('data/romania/romania_lauralaurentiu.csv')
