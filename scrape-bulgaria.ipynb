# %%
import pandas as pd
from util.bulgaria.govtach import Govtach

# %%
attrs = {
        'name'       :  'name',
        'ingredients':  'recipeIngredient',
        'total_time':   'totalTime',
        'instructions': 'recipeInstructions',
        'servings':     'recipeYield',
        'category':     'recipeCategory',
        'prep_time':    'prepTime',
        'cook_time':    'cookTime',
}
available_json = {'xpath' : "normalize-space(//script[@type='application/ld+json'][contains(text(), 'recipeIngredient')])"}
listing={'items': '//div[@class="rprev"]/div/a[2]/@href', 'next': { 'next_page_str': '?pn={}', 'type': 'random_pages' , 'max_items': 10000, 'items_per_page': 24, 'max_pages': 2120,}}
seeds = ['https://recepti.gotvach.bg/{page}?n=1']

# %%
govtach_spider = Govtach('https://recepti.gotvach.bg/', seeds=seeds, listing=listing, attrs=attrs, available_json=available_json)

# %%
govtach_spider.scrape_one_item('https://recepti.gotvach.bg/r-213251-%D0%9A%D0%B0%D0%BB%D0%BF%D0%B0%D0%B7%D0%B0%D0%BD%D1%81%D0%BA%D0%B0_%D0%B1%D0%B0%D0%BD%D0%B8%D1%86%D0%B0_%D0%BE%D1%82_%D1%81%D1%82%D0%B0%D1%80_%D1%85%D0%BB%D1%8F%D0%B1')
# Out:
# {'name': 'Калпазанска баница от стар хляб',
#  'total_time': 'PT35M',
#  'ingredients': ['стар хляб - филийки',
#   'сирене - 250 грама',
#   'яйца - 3 броя',
#   'кисело мляко - 1 ч.ч.',
#   'сода бикарбонат - 1 ч.л.',
#   'олио'],
#  'instructions': ['Намазнете тава за печене. ',
#   'Наредете на дъното филийките сух хляб , а празните пространства запълнете с малки парчета от хляба. ',
#   'Разбийте яйцата и ги смесете с киселото мляко, содата и натрошеното сирене. Залейте равномерно хляба. ',
#   'Полейте с тънка струйка олио и оставете баницата от хляб да попие добре сместа. ',
#   'Загрейте фурната на 200 градуса и я изпечете до апетитен загар. ',
#   ' Калпазанската баница от стар хляб е вкусна и много лесна.'],
#  'servings': '5',
#  'category': 'Баница',
#  'prep_time': 'PT10M',
#  'cook_time': 'PT25M'}

# %%
results_list = govtach_spider.start_scrape()
# Out:
# n of pages scraper will scrape:  416
# spider is scraping page: 1754
# scraping - multithreaded, n items:  24
# spider is scraping page: 434
# scraping - multithreaded, n items:  24
# spider is scraping page: 1630
# scraping - multithreaded, n items:  24
# spider is scraping page: 764
# scraping - multithreaded, n items:  24
# spider is scraping page: 2052
# scraping - multithreaded, n items:  21
# spider is scraping page: 1465
# scraping - multithreaded, n items:  24
# spider is scraping page: 362
# scraping - multithreaded, n items:  24
# spider is scraping page: 872
# scraping - multithreaded, n items:  24
# spider is scraping page: 941
# scraping - multithreaded, n items:  24
# spider is scraping page: 1151
# scraping - multithreaded, n items:  24
# spider is scraping page: 2046
# scraping - multithreaded, n items:  22
# json loads does not work
# Expecting value: line 1 column 1 (char 0)
# cannot decode json
# No value to decode
# local variable 'script_data' referenced before assignment
# something is wrong for item: https://recepti.gotvach.bg/r-21406-Маринован_паламуд_с_лук
# json loads does not work
# Expecting value: line 1 column 1 (char 0)
# cannot decode json
# No value to decode
# local variable 'script_data' referenced before assignment
# something is wrong for item: https://recepti.gotvach.bg/r-20712-Манджа_от_пресен_лук
# json loads does not work
# Expecting value: line 1 column 1 (char 0)
# json loads does not work
# Expecting value: line 1 column 1 (char 0)
# json loads does not work
# Expecting value: line 1 column 1 (char 0)
# cannot decode json
# No value to decode
# local variable 'script_data' referenced before assignment
# something is wrong for item: https://recepti.gotvach.bg/r-21708-Калкан_със_спанак_и_доматено_пюре
# cannot decode json
# No value to decode
# local variable 'script_data' referenced before assignment
# something is wrong for item: https://recepti.gotvach.bg/r-21402-Бигори
# json loads does not work
# Expecting value: line 1 column 1 (char 0)
# cannot decode json
# No value to decode
# local variable 'script_data' referenced before assignment
# something is wrong for item: https://recepti.gotvach.bg/r-20756-Пълнени_сухи_чушки_с_лапад
# json loads does not work
# Expecting value: line 1 column 1 (char 0)
# cannot decode json
# No value to decode
# local variable 'script_data' referenced before assignment
# something is wrong for item: https://recepti.gotvach.bg/r-25103-Патладжани_с_доматен_сос
# cannot decode json
# No value to decode
# local variable 'script_data' referenced before assignment
# something is wrong for item: https://recepti.gotvach.bg/r-21678-Задушен_сом_с_моркови_и_ябълка
# json loads does not work
# Expecting value: line 1 column 1 (char 0)
# cannot decode json
# No value to decode
# local variable 'script_data' referenced before assignment
# something is wrong for item: https://recepti.gotvach.bg/r-25101-Зелена_салата_с_млечен_дресинг
# scraping - multithreaded, n items:  24
# spider is scraping page: 1429

# %%
result_df = pd.DataFrame(results_list)

# %%
result_df
# Out:
#                                              name total_time  \
# 0                                Торта с три кори     PT105M
# 1     Яхния от зелен боб с джанки и цвят от тиква      PT60M
# 2                        Засукана пита със сирене      PT70M
# 3        Солена палачинкова торта с топено сирене      PT60M
# 4                            Бързи маслени сладки      PT50M
# ...                                           ...        ...
# 2573
# 2574
# 2575
# 2576
# 2577
#
#                                             ingredients  \
# 0     [За 1 блат, яйца - 1 бр., олио - 5 с.л., захар...
# 1     [зелен боб - 1 кг пресен, картофи - 3 бр. сред...
# 2     [за тестото, брашно - 500 гр., мая - 1/2 кубче...
# 3     [палачинки - 8 бр., шунка - 200 г, майонеза - ...
# 4     [брашно - 200 г, масло - 150 г краве, пудра за...
# ...                                                 ...
# 2573
# 2574
# 2575
# 2576
# 2577
#
#                                            instructions    servings  \
# 0     [От изброените продукти се приготвя сместа за ...  14 парчета
# 1     [Сипете вода в средно голяма тенджера и включе...           4
# 2     [Пресяваме брашното и с част от него правим ка...           4
# 3     [Всяка една от палачинките се намазва с лютени...          12
# 4     [Маслото нарязвам на парчета и го добавям към ...      20 бр.
# ...                                                 ...         ...
# 2573
# 2574
# 2575
# 2576
# 2577
#
#                category prep_time cook_time
# 0       Торти и глазури     PT45M     PT60M
# 1         Основни Ястия     PT20M     PT40M
# 2                  Хляб     PT40M     PT30M
# 3             Предястия     PT30M     PT30M
# 4     Сладки и Бисквити     PT30M     PT20M
# ...                 ...       ...       ...
# 2573
# 2574
# 2575
# 2576
# 2577
#
# [2578 rows x 8 columns]

# %%
result_df.iloc[2577]
# Out:
# name
# total_time
# ingredients
# instructions
# servings
# category
# prep_time
# cook_time
# Name: 2577, dtype: object

# %%
filter = result_df["name"] != ""

# %%
filter
# Out:
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
#         ...
# 2573    False
# 2574    False
# 2575    False
# 2576    False
# 2577    False
# Name: name, Length: 2578, dtype: bool

# %%
new_df = result_df[filter]

# %%
new_df.shape
# Out:
# (2570, 8)
