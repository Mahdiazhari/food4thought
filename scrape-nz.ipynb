# %%
import pandas as pd
import json
import requests
import random
from lxml import html
import re

from  util.spider import Spider
# from util.http_utility import get_http_headers
# from util.user_agent import get_random_ua

# %%
attrs = {
        'name':         'name',
        'ingredients':  'recipeIngredient',
        'total_time':   'totalTime',
        'instructions': 'recipeInstructions',
        'servings':     'recipeYield',
        'category':     'recipeCategory',
        'prep_time':    'prepTime',
        'cook_time':    'cookTime',
}
listing={'items': '//div[contains(@class,"fd-tile fd-recipe")]//h2//a/@href', 'next': { 'next_page_str': '?pn={}', 'type': 'url'}}
seeds = ['https://www.food.com/topic/new-zealand']
available_json = {'xpath' : "normalize-space(//script[@type='application/ld+json'][contains(text(), 'recipeIngredient')])"}

# %%
nz_spider =  Spider('https://www.food.com/', seeds= seeds, listing =listing,attrs= attrs, available_json=available_json)

# %%
nz_spider.scrape_one_item('https://www.food.com/recipe/fluffernutter-181487')
# Out:
# {'name': 'Fluffernutter',
#  'total_time': 'PT1M',
#  'ingredients': ['2 tablespoons marshmallow cream',
#   '2 tablespoons peanut butter (smooth or creamy)',
#   '2 slices bread'],
#  'instructions': ['Spread peanut butter onto one slice of bread, use as much as you want.\r',
#   'Cover with Marshmallow Fluff, use as much as you want.\r',
#   'Top with second slice of bread and enjoy!'],
#  'servings': '1 serving(s)',
#  'category': 'Lunch/Snacks',
#  'prep_time': 'PT1M',
#  'cook_time': ''}

# %%
result_list = nz_spider.start_scrape(max_pages=130) #max page is only 130
# Out:
# spider is scraping page: 1
# scraping - multithreaded, n items:  9
# spider is scraping page: 2
# scraping - multithreaded, n items:  10
# spider is scraping page: 3
# scraping - multithreaded, n items:  10
# spider is scraping page: 4
# scraping - multithreaded, n items:  10
# spider is scraping page: 5
# scraping - multithreaded, n items:  10
# spider is scraping page: 6
# scraping - multithreaded, n items:  10
# spider is scraping page: 7
# scraping - multithreaded, n items:  10
# spider is scraping page: 8
# scraping - multithreaded, n items:  10
# spider is scraping page: 9
# scraping - multithreaded, n items:  10
# spider is scraping page: 10
# scraping - multithreaded, n items:  10
# spider is scraping page: 11
# scraping - multithreaded, n items:  10
# spider is scraping page: 12
# scraping - multithreaded, n items:  10
# spider is scraping page: 13
# scraping - multithreaded, n items:  10
# spider is scraping page: 14
# scraping - multithreaded, n items:  10
# spider is scraping page: 15
# scraping - multithreaded, n items:  10
# spider is scraping page: 16
# scraping - multithreaded, n items:  10
# spider is scraping page: 17
# scraping - multithreaded, n items:  10
# spider is scraping page: 18
# scraping - multithreaded, n items:  10
# spider is scraping page: 19
# scraping - multithreaded, n items:  10
# spider is scraping page: 20
# scraping - multithreaded, n items:  10
# spider is scraping page: 21
# scraping - multithreaded, n items:  10
# spider is scraping page: 22
# scraping - multithreaded, n items:  10
# spider is scraping page: 23
# scraping - multithreaded, n items:  10
# spider is scraping page: 24
# scraping - multithreaded, n items:  10
# spider is scraping page: 25
# scraping - multithreaded, n items:  10
# spider is scraping page: 26
# scraping - multithreaded, n items:  10
# spider is scraping page: 27
# scraping - multithreaded, n items:  10
# spider is scraping page: 28
# scraping - multithreaded, n items:  10
# spider is scraping page: 29
# scraping - multithreaded, n items:  10
# spider is scraping page: 30
# scraping - multithreaded, n items:  10
# spider is scraping page: 31
# scraping - multithreaded, n items:  10
# spider is scraping page: 32
# scraping - multithreaded, n items:  10
# spider is scraping page: 33
# scraping - multithreaded, n items:  10
# spider is scraping page: 34
# scraping - multithreaded, n items:  10
# spider is scraping page: 35
# scraping - multithreaded, n items:  10
# spider is scraping page: 36
# scraping - multithreaded, n items:  10
# spider is scraping page: 37
# scraping - multithreaded, n items:  10
# spider is scraping page: 38
# scraping - multithreaded, n items:  10
# spider is scraping page: 39
# scraping - multithreaded, n items:  10
# spider is scraping page: 40
# scraping - multithreaded, n items:  10
# spider is scraping page: 41
# scraping - multithreaded, n items:  10
# spider is scraping page: 42
# scraping - multithreaded, n items:  10
# spider is scraping page: 43
# scraping - multithreaded, n items:  10
# spider is scraping page: 44
# scraping - multithreaded, n items:  10
# spider is scraping page: 45
# scraping - multithreaded, n items:  10
# spider is scraping page: 46
# scraping - multithreaded, n items:  10
# spider is scraping page: 47
# scraping - multithreaded, n items:  10
# spider is scraping page: 48
# scraping - multithreaded, n items:  10
# spider is scraping page: 49
# scraping - multithreaded, n items:  10
# spider is scraping page: 50
# scraping - multithreaded, n items:  10
# spider is scraping page: 51
# scraping - multithreaded, n items:  10
# spider is scraping page: 52
# scraping - multithreaded, n items:  10
# spider is scraping page: 53
# scraping - multithreaded, n items:  10
# spider is scraping page: 54
# scraping - multithreaded, n items:  10
# spider is scraping page: 55
# scraping - multithreaded, n items:  10
# spider is scraping page: 56
# scraping - multithreaded, n items:  10
# spider is scraping page: 57
# scraping - multithreaded, n items:  10
# spider is scraping page: 58
# scraping - multithreaded, n items:  10
# spider is scraping page: 59
# scraping - multithreaded, n items:  10
# spider is scraping page: 60
# scraping - multithreaded, n items:  10
# spider is scraping page: 61
# scraping - multithreaded, n items:  10
# spider is scraping page: 62
# scraping - multithreaded, n items:  10
# spider is scraping page: 63
# scraping - multithreaded, n items:  10
# spider is scraping page: 64
# scraping - multithreaded, n items:  10
# spider is scraping page: 65
# scraping - multithreaded, n items:  10
# spider is scraping page: 66
# scraping - multithreaded, n items:  10
# spider is scraping page: 67
# scraping - multithreaded, n items:  10
# spider is scraping page: 68
# scraping - multithreaded, n items:  10
# spider is scraping page: 69
# scraping - multithreaded, n items:  10
# spider is scraping page: 70
# scraping - multithreaded, n items:  10
# spider is scraping page: 71
# scraping - multithreaded, n items:  10
# spider is scraping page: 72
# scraping - multithreaded, n items:  10
# spider is scraping page: 73
# scraping - multithreaded, n items:  10
# spider is scraping page: 74
# scraping - multithreaded, n items:  10
# spider is scraping page: 75
# scraping - multithreaded, n items:  10
# spider is scraping page: 76
# scraping - multithreaded, n items:  10
# spider is scraping page: 77
# scraping - multithreaded, n items:  10
# spider is scraping page: 78
# scraping - multithreaded, n items:  10
# spider is scraping page: 79
# scraping - multithreaded, n items:  10
# spider is scraping page: 80
# scraping - multithreaded, n items:  10
# spider is scraping page: 81
# scraping - multithreaded, n items:  10
# spider is scraping page: 82
# scraping - multithreaded, n items:  10
# spider is scraping page: 83
# scraping - multithreaded, n items:  10
# spider is scraping page: 84
# scraping - multithreaded, n items:  10
# spider is scraping page: 85
# scraping - multithreaded, n items:  10
# spider is scraping page: 86
# scraping - multithreaded, n items:  10
# spider is scraping page: 87
# scraping - multithreaded, n items:  10
# spider is scraping page: 88
# scraping - multithreaded, n items:  10
# spider is scraping page: 89
# scraping - multithreaded, n items:  10
# spider is scraping page: 90
# scraping - multithreaded, n items:  10
# spider is scraping page: 91
# scraping - multithreaded, n items:  10
# spider is scraping page: 92
# scraping - multithreaded, n items:  10
# spider is scraping page: 93
# scraping - multithreaded, n items:  10
# spider is scraping page: 94
# scraping - multithreaded, n items:  10
# spider is scraping page: 95
# scraping - multithreaded, n items:  10
# spider is scraping page: 96
# scraping - multithreaded, n items:  10
# spider is scraping page: 97
# scraping - multithreaded, n items:  10
# spider is scraping page: 98
# scraping - multithreaded, n items:  10
# spider is scraping page: 99
# scraping - multithreaded, n items:  10
# spider is scraping page: 100
# scraping - multithreaded, n items:  10
# spider is scraping page: 101
# scraping - multithreaded, n items:  10
# spider is scraping page: 102
# scraping - multithreaded, n items:  10
# spider is scraping page: 103
# scraping - multithreaded, n items:  10
# spider is scraping page: 104
# scraping - multithreaded, n items:  10
# spider is scraping page: 105
# scraping - multithreaded, n items:  10
# spider is scraping page: 106
# scraping - multithreaded, n items:  10
# spider is scraping page: 107
# scraping - multithreaded, n items:  10
# spider is scraping page: 108
# scraping - multithreaded, n items:  10
# spider is scraping page: 109
# scraping - multithreaded, n items:  10
# spider is scraping page: 110
# scraping - multithreaded, n items:  10
# spider is scraping page: 111
# scraping - multithreaded, n items:  10
# spider is scraping page: 112
# scraping - multithreaded, n items:  10
# spider is scraping page: 113
# scraping - multithreaded, n items:  10
# spider is scraping page: 114
# scraping - multithreaded, n items:  10
# spider is scraping page: 115
# scraping - multithreaded, n items:  10
# spider is scraping page: 116
# scraping - multithreaded, n items:  10
# spider is scraping page: 117
# scraping - multithreaded, n items:  10
# spider is scraping page: 118
# scraping - multithreaded, n items:  10
# spider is scraping page: 119
# scraping - multithreaded, n items:  10
# spider is scraping page: 120
# scraping - multithreaded, n items:  10
# spider is scraping page: 121
# scraping - multithreaded, n items:  10
# spider is scraping page: 122
# scraping - multithreaded, n items:  10
# spider is scraping page: 123
# scraping - multithreaded, n items:  10
# spider is scraping page: 124
# scraping - multithreaded, n items:  10
# spider is scraping page: 125
# scraping - multithreaded, n items:  10
# spider is scraping page: 126
# scraping - multithreaded, n items:  10
# spider is scraping page: 127
# scraping - multithreaded, n items:  10
# spider is scraping page: 128
# scraping - multithreaded, n items:  10
# spider is scraping page: 129
# scraping - multithreaded, n items:  10
# spider is scraping page: 130
# Cannot open the menu url, status code = 410, url= https://www.food.com/topic/new-zealand?pn=130

# %%
result_df = pd.DataFrame(result_list)

# %%
result_df
# Out:
#                              name total_time  \
# 0                 Big Fruit Salad      PT30M
# 1                  Edmonds Scones      PT20M
# 2                   Settler's Pie    PT1H10M
# 3          Coconut Cream Truffles    PT2H25M
# 4                         Pavlova    PT1H50M
# ...                           ...        ...
# 1284    N Z's Best Salad Dressing       PT2M
# 1285       Raspberry Lavender Jam      PT35M
# 1286      Condensed Milk Dressing     PT2H5M
# 1287  Kumara Salad (sweet potato)      PT40M
# 1288    Lemon Meringue Cheesecake      PT35M
#
#                                             ingredients  \
# 0     [1 medium cantaloupe, 1 medium honeydew melon,...
# 1     [3 cups plain flour, 6 teaspoons baking powder...
# 2     [1 cup flour, 4 ounces butter, 2 teaspoons vin...
# 3     [375 g white chocolate, 150 g butter, 1/2 cup ...
# 4     [4 egg whites, 1 teaspoon vanilla essence, 2 t...
# ...                                                 ...
# 1284  [1 (395 g) can sweetened condensed milk, 1 cup...
# 1285  [3 cups fresh raspberries (you can use frozen ...
# 1286  [1 (397 g) can condensed milk, 3/4 cup vinegar...
# 1287  [1 1/2 tablespoons oil, 2 tablespoons pineappl...
# 1288  [2 cups graham cracker crumbs or 2 cups tea bi...
#
#                                            instructions  \
# 0     [Cut the 2 melons in half, then scrap out the ...
# 1     [Sift flour, baking powder and salt into a bow...
# 2     [Mix the flour and butter to a sandy texture.,...
# 3     [Gently melt butter and white chocolate in lar...
# 4     [Beat egg whites and cornflour well with elect...
# ...                                                 ...
# 1284  [Place all ingredients into a bowl and beat we...
# 1285  [The night before you make this jam put the ra...
# 1286  [Put approximately 3 tablespoons of condensed ...
# 1287  [Combine oil, pineapple and lemon juice in bow...
# 1288  [Combined biscuits and butter., Press into a 2...
#
#                      servings         category prep_time cook_time
# 0                8 serving(s)     Lunch/Snacks     PT30M
# 1               12 serving(s)           Scones     PT10M     PT10M
# 2     1 pie, 16-20 serving(s)      Savory Pies     PT30M     PT40M
# 3               50 chocolates            Candy     PT25M      PT2H
# 4                8 serving(s)          Dessert     PT20M   PT1H30M
# ...                       ...              ...       ...       ...
# 1284                   4 cups  Salad Dressings      PT2M
# 1285           750 g - approx      Raspberries     PT10M     PT25M
# 1286                   2 cups  Salad Dressings      PT5M      PT2H
# 1287            10 serving(s)        Pineapple     PT15M     PT25M
# 1288            10 serving(s)       Cheesecake     PT25M     PT10M
#
# [1289 rows x 8 columns]

# %%
result_df.to_csv('data/new-zealand/food_com_nz.csv')
