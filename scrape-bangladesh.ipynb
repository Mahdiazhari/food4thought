# %%
from util.bangladesh.thebangladeshikitchen import BangladeshiKitchen
import pandas as pd

# %%
attrs = {
        'name':         'normalize-space(//span[@property="v:title"]//text())',
        'ingredients':  '//div[@id="recipe_content_pro"]/ul//li//text()',
        'total_time':   'normalize-space(//div[@class="time-single-pro"]/span//text())',
        'instructions': '//div[@id="recipe_content_pro"]/ol//li//text()',
        'servings':     '',
        'category':     'normalize-space(//div[@id="category-talisa-pro"]//li//text())',
        'prep_time':    '',
        'cook_time':    '',
}

listing={'items': '//h4[@class="menu-title"]/a/@href', 'next': { 'next_page_str': 'page/{}/', 'type': 'url'}}
seeds = ['https://www.thebangladeshikitchen.com/recipes/']
available_json= {}

# %%
bangladesh_spider = BangladeshiKitchen('https://www.thebangladeshikitchen.com', seeds= seeds, listing =listing,attrs= attrs, available_json=available_json)

# %%
bangladesh_spider.scrape_one_item('https://www.thebangladeshikitchen.com/recipes/chicken-pakora/')
# Out:
# {'name': 'Chicken Pakora',
#  'total_time': '2 hr 15 minutes',
#  'ingredients': ['2 regular size boneless chicken breasts, washed and finely chopped',
#   '\xa0tbsp ginger paste',
#   '1 tsp garlic paste',
#   '1/2 tsp garam masala powder',
#   '1/2 tsp salt',
#   '5 green chilli, finely chopped',
#   '1 tbsp lime juice',
#   '1 medium onion, finely chopped (optional)',
#   '1 \xa0tbsp finely chopped cilantro',
#   '2 tbsp gram flour',
#   'Oil to fry'],
#  'instructions': ['Directions',
#   '1. Marinate the chicken with ginger, garlic, garam masala and lime juice. Keep aside for 2 hours (can also be marinated overnight, or in the morning to fry in the afternoon/evening, in that case, add lime juice a few hours before frying).',
#   '2. Add the salt, green chilli, cilantro and onions (if desired) and mix.',
#   '3. Add gram flour and mix well. Divide into balls.',
#   '4. Heat oil and deep fry on medium heat. (I usually prick the balls with a fork during frying to ensure that the pakora is evenly cooked on the inside as well.) The color should be a light golden brown.',
#   '5. Serve hot.',
#   '\xa0'],
#  'servings': '12 pc',
#  'category': 'Side dishes',
#  'prep_time': '2 hours',
#  'cook_time': '15 minutes'}

# %%
bangladesh_spider.scrape_one_item('https://www.thebangladeshikitchen.com/recipes/kata-moshlar-mangsho-meat-with-whole-spices/')
# Out:
# this item: https://www.thebangladeshikitchen.com/recipes/kata-moshlar-mangsho-meat-with-whole-spices/
# item has no prep time data
# has no cook time data
# has no servings data
# {'name': 'Kata Moshlar Mangsho – Meat with whole spices',
#  'total_time': '',
#  'ingredients': ['1 kg beef, cubed',
#   '1 large onion thinky sliced',
#   '1 tbsp ginger, julienned',
#   '1 tbsp garlic, chopped',
#   '6-8 dry red chilies',
#   '3 cardamom',
#   '1″ cinnamon stick',
#   '1 bay leaf',
#   '6-7 black pepper',
#   '4-5 clove',
#   '2 tablespoon vinegar',
#   '½ cup yogurt',
#   '½ cup oil or ghee',
#   'Salt to taste (1 to 1\xa0½ tsp)'],
#  'instructions': ['Marinate the meat with vinegar for at least 30 minutes',
#   'Heat up the oil in a dutch oven over medium heat',
#   'Add the beef and all the other ingredients except for the yogurt',
#   'Saute for 10-15 minutes until the onions are translucent',
#   'Add the yogurt and 1-2 cups of water',
#   'Cook over medium heat until done (45 minutes to 1 hour)',
#   'Or preheat an oven to 175 degrees Celsius and bake covered for about 1 hour'],
#  'servings': '',
#  'category': 'Main Dishes',
#  'prep_time': '',
#  'cook_time': ''}

# %%
result_list = bangladesh_spider.start_scrape()
# Out:
# spider is scraping page: 1
# this item: https://www.thebangladeshikitchen.com/recipes/shahi-rezala/
# item has no prep time data
# has no cook time data
# has no servings data
# this item: https://www.thebangladeshikitchen.com/recipes/bhuna-khichuri/
# item has no prep time data
# has no cook time data
# has no servings data
# this item: https://www.thebangladeshikitchen.com/recipes/basmati-rice/
# item has no prep time data
# has no cook time data
# has no servings data
# has no servings data
# this item: https://www.thebangladeshikitchen.com/recipes/kata-moshlar-mangsho-meat-with-whole-spices/
# item has no prep time data
# has no cook time data
# has no servings data
# scraping - multithreaded, n items:  12
# spider is scraping page: 2
# this item: https://www.thebangladeshikitchen.com/recipes/rui-fish-in-a-spicy-tomato-and-onion-sauce/
# item has no prep time data
# has no cook time data
# has no servings data
# this item: https://www.thebangladeshikitchen.com/recipes/fish-dopeaja-fish-with-onions/
# item has no prep time data
# has no cook time data
# has no servings data
# this item: https://www.thebangladeshikitchen.com/recipes/shrimp-with-cilantro-and-tomato/
# item has no prep time data
# has no cook time data
# has no servings data
# this item: https://www.thebangladeshikitchen.com/recipes/palong-shaak-bhaji/
# item has no prep time data
# has no cook time data
# has no servings data
# this item: https://www.thebangladeshikitchen.com/recipes/tikiya-kabab/
# item has no prep time data
# has no cook time data
# has no servings data
# this item: https://www.thebangladeshikitchen.com/recipes/cauliflower-with-bengali-five-spice/
# item has no prep time data
# has no cook time data
# has no servings data
# scraping - multithreaded, n items:  12
# spider is scraping page: 3
# this item: https://www.thebangladeshikitchen.com/recipes/beef-tehari/
# item has no prep time data
# has no cook time data
# has no servings data
# this item: https://www.thebangladeshikitchen.com/recipes/rui-machher-jhol-1/
# item has no prep time data
# has no cook time data
# has no servings data
# has no servings data
# this item: https://www.thebangladeshikitchen.com/recipes/lauer-khosha-bhaji-fried-bottle-gourd-peel/
# item has no prep time data
# has no cook time data
# has no servings data
# this item: https://www.thebangladeshikitchen.com/recipes/bengali-egg-halua-halva/
# item has no prep time data
# has no cook time data
# has no servings data
# this item: https://www.thebangladeshikitchen.com/recipes/chat-or-chatpati-spice-mix/
# item has no prep time data
# has no cook time data
# has no servings data
# scraping - multithreaded, n items:  12
# spider is scraping page: 4
# this item: https://www.thebangladeshikitchen.com/recipes/fuchka/
# item has no prep time data
# has no cook time data
# has no servings data
# this item: https://www.thebangladeshikitchen.com/recipes/bhapa-chingri-steamed-shrimp-with-mustard-and-green-chili/
# item has no prep time data
# has no cook time data
# has no servings data
# this item: https://www.thebangladeshikitchen.com/recipes/tandoori-spice-mix/
# item has no prep time data
# has no cook time data
# has no servings data
# this item: https://www.thebangladeshikitchen.com/recipes/ilish-polau-hilsa-pilaf/
# item has no prep time data
# has no cook time data
# has no servings data
# this item: https://www.thebangladeshikitchen.com/recipes/vegetable-pulao-1/
# item has no prep time data
# has no cook time data
# has no servings data
# scraping - multithreaded, n items:  11
# spider is scraping page: 5
# Cannot open the menu url, status code = 404, url= https://www.thebangladeshikitchen.com/recipes/page/5/

# %%
result_df = pd.DataFrame(result_list)

# %%
result_df
# Out:
#                                                  name         total_time  \
# 0                                      Chicken Pakora    2 hr 15 minutes
# 1    Stirfried Cabbage with Garlic and Bengali Spices         40 minutes
# 2                                        Basmati Rice
# 3            Spicy Dry Chicken – Kosha Murgir Mangsho             1 hour
# 4                                      Bhuna Khichuri
# 5                          Mutton Curry with Potatoes         60 minutes
# 6                                         Panch Foron              1 min
# 7                                        Shahi Rezala
# 8                             Homestyle Chicken Korma  1 hour 15 minutes
# 9       Kata Moshlar Mangsho – Meat with whole spices
# 10                 Baked fish in a light yogurt sauce          1.5 hours
# 11      Yogurt and Cilantro marinated grilled chicken               1 hr
# 12                                         Fish Korma             1 hour
# 13                    Fish Dopeaja * Fish with Onions
# 14                                      Beef Vindaloo          1.5 hours
# 15                          Mashur Daal – Red Lentils          1.5 hours
# 16                    Shrimp with cilantro and tomato
# 17                             Bhuna Khichuri – basic         45 minutes
# 18                 Palong Shaak Bhaji – Spinach Bhaji
# 19         Rui fish in a spicy tomato and onion sauce
# 20                                       Tikiya Kabab
# 21                               Dharosh Bhaji * Okra         30 minutes
# 22                Cauliflower with Bengali five spice
# 23                                     Beef Shingaras          1.5 hours
# 24                          Bengali Egg Halua (Halva)
# 25                      Lau Bhaji – Bottlegourd Bhaji         30 minutes
# 26                   Chichinga Bhaji – Fried Zuchhini         45 minutes
# 27                                        Beef Tehari
# 28                               Rui Machher Jhol – 1
# 29               Acorn Squash Bhaji with Panch Phoron         30 minutes
# 30       Lauer Khosha Bhaji – Fried Bottle Gourd Peel
# 31             Shorshe Ilish – Hilsa in mustard sauce          1.5 hours
# 32                     Kosha Mangsho – Sauteed Mutton         1.25 hours
# 33         Rui Machher Jhaal Kalia – Spicy Fish Kalia         1.25 hours
# 34                         Chat or Chatpati Spice Mix
# 35                Tomato Begun – Eggplant with tomato         45 minutes
# 36                                              Luchi          1.5 hours
# 37                     Aloo Jeera (Potato with cumin)               1 hr
# 38                                   Tandoori Chicken             1 hour
# 39                   Begun Bhaji – Fried Eggplant – 1         40 minutes
# 40  Bhapa Chingri – Steamed shrimp with mustard an...
# 41                                 Tandoori Spice Mix
# 42                                               Naan            2 hours
# 43                                             Fuchka
# 44                          Ilish Polau = Hilsa Pilaf
# 45                                Vegetable Pulao – 1
# 46                              Bengali Beef Cabernet          1.5 hours
#
#                                           ingredients  \
# 0   [2 regular size boneless chicken breasts, wash...
# 1   [1/2 head of cabbage shredded thinly, 2 tbsp g...
# 2   [1 cup Basmati rice, 1 small onion, 3 medium c...
# 3   [Chicken 100 grams. A whole chicken cut up int...
# 4   [MoogdAl 1 cup, PolAu Rice  2 cups, Finely dic...
# 5   [1 kg,  ‏Mutton, 4 pcs,  ‏Potato, 1/2 cup,  ‏C...
# 6   [cumin seeds, fennel seeds, fenugreek seeds, b...
# 7                                                  []
# 8   [2,  , pounds bone-in chicken (dark meat best)...
# 9   [1 kg beef, cubed, 1 large onion thinky sliced...
# 10  [3 tbsp oil, 2 tbsp unsalted cold butter or gh...
# 11  [One chicken, cut into 6-8 pieces, 2 cups of y...
# 12  [Fish 1 kg, Yogurt 1/2 cup, Onion paste 1/2 cu...
# 13  [Fish (preferably small, cut into small pieces...
# 14  [Beef, cut into approximately 1″ cubes, 1 poun...
# 15  [1 cup red lentils (moshur/masur daal), 1/2 cu...
# 16  [1 lb shrimp, deveined, 1 medium onion, thinly...
# 17  [1 cup Moong daal, 1 cup Basmati or other long...
# 18  [1 pound chopped spinach, 1 tsp salt, 1 tsp pa...
# 19  [2 lbs of rui steaks, 2 1/4 tsp salt, 1 1/2 ts...
# 20  [1 oz (25 g) channa dhal, split, 8 oz (225 g) ...
# 21  [2 pounds of fresh okra cut into quarter inch ...
# 22  [1-2 tbsp oil, 1 small onion, finely chopped, ...
# 23  [1 pound ground beef, 1 onion, chopped, 1 teas...
# 24  [3large eggs, 1 quart of full cream milk, 8 tb...
# 25  [1 medium , lau,  or bottle gourd, 2 tsp whole...
# 26  [1 tablespoon oil, 1/2 tsp kalojira (nigella),...
# 27  [Beef 1 kg (2 lbs), Onion paste  – 1/2 cup, Ga...
# 28  [2 lbs of Rui steaks, 4-5 medium potatoes, 2 t...
# 29  [I medium sized acorn squash, 1 tablespoon ghe...
# 30  [Add the peels, salt and 1/4 of the turmeric i...
# 31  [1 Ilish (Hilsha) fish, cut into steaks, 1 tab...
# 32  [2 lbs of mutton (or lamb, or beef), cubed, 2 ...
# 33  [2 lb fish, cut into 3/4 inch steaks, 1 tsp cu...
# 34  [2 tablespoons cumin seeds, 2 tablespoons cori...
# 35  [1 medium to large eggplant (cut to 1/2 inch c...
# 36  [4 cups flour, 1 tbsp  baking powder, 2 tbsp p...
# 37  [3 tablespoons vegetable oil, 1 dry red chilli...
# 38  [1/2 of the , tandoori spice mix, 2 lbs chicke...
# 39  [One large egg plant sliced 1/4 inch thick, 1 ...
# 40  [1 lb medium/large shrimp, cleaned and deveine...
# 41  [10 cloves, seeds from 3 cardamoms, 2 tsp salt...
# 42  [1 1/2 pkg active dry yeast, 1 tsp sugar, 4 1/...
# 43                                                 []
# 44  [6-8 ilish (hilsa) pieces, 1/2 tsp turmeric, 2...
# 45  [2 cups rice, 1 cup mixed vegetables, diced, 2...
# 46  [2 tbsp cooking oil, 2 pounds beef, cubed to s...
#
#                                          instructions servings  \
# 0   [Directions, 1. Marinate the chicken with ging...    12 pc
# 1   [Heat the ghee  in a wok or large skillet over...      4-6
# 2   [Wash the rice in cool water, squeezing gently...
# 3   [Heat the mustard oil in a deep wok or saucepa...      4-6
# 4   [Wash the rice, Fry the dAl separtely for a wh...
# 5   [1. Cut the meat into small pieces, wash and d...        6
# 6                              [Mix them together. 🙂]
# 7                                                  []
# 8   [Thinly slice one onion and set aside, Roughly...        4
# 9   [Marinate the meat with vinegar for at least 3...
# 10  [Preheat the oven to 325 degrees, Heat the oil...        4
# 11  [Put all the ingredients into a blender and bl...      2-4
# 12  [Use large fish for korma. Do not cut the fish...        4
# 13  [Works best with small fish. Out here in the l...
# 14  [Heat the oil in a saute pan and fry onions un...      4-6
# 15  [Daal preparations, where pulses (dried beans,...        4
# 16  [This is one of my comfort foods. The taste be...
# 17  [Bring the ghee to heat on a saucepan over med...      4-6
# 18  [If there is rice to be had, there will have t...
# 19  [Pat the steaks dry and rub them down with the...
# 20  [Soak the daal overnight, then boil in twice i...
# 21  [In a preferably non-stick frying pan, heat oi...        4
# 22  [I have been particularly fond of cauliflower ...
# 23  [Spray large non-stick skillet with cooking sp...      4-6
# 24  [Pour the milk in a saucepan and add half of t...
# 25  [Peel and then slice the gourd into very thin ...      2-4
# 26  [Heat the oil ina  pan over medium high heat, ...        4
# 27  [Tehari is a rice dish with cooked with meat a...
# 28  [Marinate the fish steaks with 1 tsp each of t...
# 29  [Peel the squash, and chop into 1 to 1/2 inch ...
# 30  [Bengalis tend to not waste any food and will ...
# 31  [Rub some salt and turmeric on the fish steaks...        4
# 32  [Mix the meat with the next 12 ingredients and...      4-6
# 33  [Marinate the fish with 1 tsp turmeric and 1 t...      4-6
# 34  [Dry roast the cumin and coriander seeds, Ligh...
# 35  [Heat the oil in a pan over medium to high hea...      2-4
# 36  [In a large bowl, mix flour with baking powder...        2
# 37  [Heat the oil in a frying pan, Add the whole d...        2
# 38  [Marinate chicken pieces in spice mixture from...      4-6
# 39  [This is one of my go-to comfort foods. Very e...      2-4
# 40  [Rub the shrimp with the 1/4 cup of salt and s...
# 41  [Grind the above mix in a spice grinder, Store...
# 42  [Put yeast, sugar and 5 tbsp water in small bo...        4
# 43  [Also known as Panipuri in Northern India and ...
# 44  [Marinade the fish with 1 tsp ginger, 1 tsp sa...
# 45  [Heat ghee in a pot over medium heat, Saute th...
# 46  [I have started to experiment with different c...      4-6
#
#              category        prep_time     cook_time
# 0         Side dishes          2 hours    15 minutes
# 1         Side dishes       10 minutes    30 minutes
# 2                Rice
# 3         Main Dishes       15 minutes    45 minutes
# 4    Lentils and daal
# 5                           15 minutes    45 minutes
# 6         Spice Mixes            1 min         0 min
# 7         Main Dishes
# 8         Main Dishes       30 minutes    45 minutes
# 9         Main Dishes
# 10        Main Dishes    30-45 minutes  30-45 miutes
# 11  Kababs and Grills       20 minutes    40 minutes
# 12        Main Dishes       20 minutes    40 minutes
# 13        Main Dishes
# 14        Main Dishes       30 minutes        1 hour
# 15   Lentils and daal       30 minutes        1 hour
# 16        Main Dishes
# 17   Lentils and daal       15 minutes    30 minutes
# 18        Side dishes
# 19        Main Dishes
# 20  Kababs and Grills
# 21        Side dishes       20 minutes    20 minutes
# 22        Side dishes
# 23             Snacks       45 minutes    45 minutes
# 24            Dessert
# 25        Side dishes       15 minutes    15 minutes
# 26        Side dishes       15 minutes    30 minutes
# 27        Main Dishes
# 28        Main Dishes
# 29        Side dishes       10 minutes    20 minutes
# 30        Side dishes
# 31        Main Dishes       45 minutes    45 minutes
# 32        Main Dishes       30 minutes    45 minutes
# 33        Main Dishes       30 minutes    45 minutes
# 34             Snacks
# 35        Side dishes       15 minutes    30 minutes
# 36             Breads           1 hour     0.5 hours
# 37        Side dishes       30 minutes    30 minutes
# 38        Main Dishes       15 minutes    45 minutes
# 39        Side dishes       10 minutes    30 minutes
# 40        Main Dishes
# 41        Spice Mixes
# 42             Breads           1 hour        1 hour
# 43             Snacks
# 44        Main Dishes
# 45               Rice
# 46        Main Dishes  15 - 30 minutes   1-1.5 hours

# %%
result_df.to_csv('data/bangladesh/bangladesh.csv')
