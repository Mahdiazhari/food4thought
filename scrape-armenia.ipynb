# %%
from util.spider import Spider
import pandas as pd

# %%
attrs = {
        'name':         'name',
        'ingredients':  'recipeIngredient',
        'total_time':   'totalTime',
        'instructions': 'recipeInstructions',
        'servings':     'recipeYield',
        'category':     'recipeCategory',
        'prep_time':    'prepTime',
        'cook_time':    'cookTime',
}
available_json = {'xpath' : "normalize-space(//script[@type='application/ld+json'][contains(text(), 'recipeIngredient')])"}
seeds = ['https://thearmeniankitchen.com/category/main-dishes', 

        'https://thearmeniankitchen.com/category/soups', 
        
        'https://thearmeniankitchen.com/category/appetizers',

        'https://thearmeniankitchen.com/category/salads',

        'https://thearmeniankitchen.com/category/grain-legumes',


        'https://thearmeniankitchen.com/category/vegetables',



        'https://thearmeniankitchen.com/category/fruits',

        'https://thearmeniankitchen.com/category/herbs-spices',



        'https://thearmeniankitchen.com/category/breads-boregs',



        'https://thearmeniankitchen.com/category/eggs-cheese-yogurt',


        'https://thearmeniankitchen.com/category/meatless-lenten-dishes',


        
          ]
listing={'items': '//div[@class="blog-grid-wrap"]//h2[@class="entry-title"]/a/@href', 'next': { 'next_page_str': '/page/{}', 'type': 'url'}}

# %%
custom_header_template = { #setup custom header because this website requires certain headers
        'referer': 'https://thearmeniankitchen.com/',
        'Accept-Language': '*',
        'Accept-Encoding': '*', 
        'sec-ch-ua': '" Not A;Brand";v="99", "Chromium";v="100", "Google Chrome";v="100"',
        'sec-fetch-site' : 'same-origin',
        #'cookie': '_ga=GA1.2.1978438003.1649681893; cb-enabled=enabled; _gid=GA1.2.1870821735.1650271735; ao-fpgad=%7B%22fpcRequired%22%3Afalse%2C%22checkTS%22%3A1650271735392%2C%22domain%22%3A%22lauralaurentiu.ro%22%7D; __gads=ID=3dd1ab9c6ddf9fc9-2289c17b2ed20094:T=1649681893:RT=1650271783:S=ALNI_MbZpRpmkjwza5LhQQ1HkGR0H4wMjQ',
        'user-agent': ''}

# %%
armenia_spider = Spider('https://thearmeniankitchen.com', seeds, listing,attrs, available_json=available_json, header=custom_header_template)

# %%
armenia_spider.scrape_one_item('https://thearmeniankitchen.com/leeks-peas-and-sorrel-soup/') #1st variation of recipeJSON
# Out:
# {'name': 'Sorrel Soup with Leeks and Peas',
#  'total_time': 'PT30M',
#  'ingredients': ['½ cup leeks - white part only (thoroughly rinsed and cut into thin circles)',
#   '1 Tbsp. olive oil',
#   '1½ cups fresh -or- frozen baby peas, thawed',
#   '3 to 3½ cups water, divided (vegetable broth may be substituted)',
#   '1 16.9 oz jar preserved sorrel, undrained',
#   '*Salt and Pepper',
#   'parsley, chives, or scallions (finely chopped)',
#   'plain yogurt (not Greek-style), combined with a little olive oil (for drizzling)'],
#  'instructions': ['Heat a 3-to-4-quart pot on medium heat. Heat the olive oil and then add the leeks. Add 1 cup of the water (or vegetable broth, if using). Cover and simmer for about 10 minutes.',
#   'Remove the lid; add the peas, preserved sorrel with its liquid, and 2 to 21/2 cups of water or broth. Bring to a simmer. Cook just until the peas are done, about 3-5 minutes. (If using fresh sorrel, cook until peas are tender, then add fresh sorrel and cook until wilted, about 1 to 2 minutes.)',
#   'Using an immersion blender, regular blender or food processor, blend the soup into a smooth puree.',
#   'Season with a little bit of pepper and additional salt, if necessary. Reminder: Preserved sorrel tends to be salty so taste soup before adding any additional salt.',
#   'Garnish the soup with chopped parsley, chives, or scallions, if desired. Or drizzle with plain yogurt-olive oil mixture.',
#   'Serve with pita bread, crackers, or a bread of your choice'],
#  'servings': ['4'],
#  'category': ['Soup'],
#  'prep_time': 'PT15M',
#  'cook_time': 'PT15M'}

# %%
armenia_spider.scrape_one_item('https://thearmeniankitchen.com/lamb-shank-gouvedge/') #2nd variation of recipe JSON
# Out:
# {'name': 'Lamb Shank Gouvedge',
#  'total_time': 'PT945M',
#  'ingredients': ['4 large lamb shanks (trimmed of fat)',
#   'lamb broth (See Day 1 preparation for details)',
#   '6 oz tomato paste',
#   '15 oz can diced tomatoes (with liquid, optional)',
#   '1 lb fresh green beans (end trimmed, cut into 2” pieces)',
#   '2 medium zucchini (cut into large chunks)',
#   '1 large eggplant (cut into cubes)',
#   '1 lb okra (cut into small pieces, optional)',
#   '2 medium red or orange peppers (seeds removed, and cut into chunks)',
#   '1 large onion (sliced)',
#   '3 garlic cloves (peeled and thinly sliced)',
#   '1 bunch flat leaf parsley',
#   '2 tbsp olive oil',
#   'salt (to taste)',
#   'pepper (to taste)',
#   'allspice (to taste)',
#   'oregano (to taste)',
#   'paprika (to taste)',
#   'Aleppo pepper (to taste)',
#   'cayenne pepper (to taste)',
#   'ground coriander seeds (to taste)'],
#  'instructions': ['Place the trimmed lamb shanks in a large pot with enough water to cover. Bring to a boil, skimming any residue from the surface during the cooking process.\xa0',
#   'Reduce temperature to medium-low; place a cover, tilted, on the pot.\xa0',
#   'Cook for 1 to 1 ½ hours, or until the meat is tender enough to easily be removed from the bones.\xa0',
#   'Periodically check the water level; do not let it all evaporate. Add more as needed. You should end up with at least 3 cups of broth.',
#   'While the lamb cooks, cut all of the vegetables as noted above.',
#   'Remove shanks from the liquid; place in a container, cover and refrigerate.\xa0',
#   'Strain the liquid from the pot; discard any unwanted particles. Place strained broth in a bowl, cover and refrigerate overnight.',
#   'Special Note: Check the ends of the bones for what Dikranagerdsis call ,&#039;dzoodz&#039;, or\xa0bone marrow. Scoop it from the open end of the bone and eat it up!',
#   'Remove meat from the bones and cut lamb into bite-sized pieces. Place meat in a bowl.',
#   'Remove and discard the layer of fat from the surface of the chilled, gelatinous lamb broth.',
#   'Using a large pot, sauté the onions and peppers in a few Tbsp. olive oil over medium-high heat.',
#   'Season with a sprinkle of salt and pepper as it cooks.\xa0Add the congealed broth.',
#   'Add the tomato paste, stirring gently until paste is blended with the broth. Add lamb pieces.',
#   'Add the prepared vegetables. Season with salt, pepper, and any combination of herbs and spices as listed, to suit your taste.',
#   'Cook, covered, on low heat, for about 45 min. to 1 hour. Stir occasionally, making sure the liquid hasn’t evaporated. Add water, if necessary.',
#   'Preheat the oven to 350°- 375° F (ovens vary). Lightly oil a 9” x 13” casserole dish.\xa0Evenly spread the lamb-vegetable mixture. Cover pan with foil and bake for 1 hour. Remove foil and bake an additional 45 minutes or until top begins to brown.',
#   'While gouvedge is baking, make rice or bulgur pilaf to serve as a side dish. A side of plain yogurt is always a welcome addition, too.'],
#  'servings': ['6', '6 servings'],
#  'category': ['Main Course'],
#  'prep_time': 'PT120M',
#  'cook_time': 'PT105M'}

# %%
result_list = armenia_spider.start_scrape()
# Out:
# spider is scraping page: 1
# scraping - multithreaded, n items:  10
# spider is scraping page: 2
# json loads does not work
# Expecting value: line 1 column 1 (char 0)
# cannot decode json
# No value to decode
# local variable 'script_data' referenced before assignment
# something is wrong for item: https://thearmeniankitchen.com/lentil-soup-with-meatballs/
# json loads does not work
# Expecting value: line 1 column 1 (char 0)
# cannot decode json
# No value to decode
# local variable 'script_data' referenced before assignment
# something is wrong for item: https://thearmeniankitchen.com/sonia-tashjian-celebrates-foods-of/
# json loads does not work
# Expecting value: line 1 column 1 (char 0)
# cannot decode json
# No value to decode
# local variable 'script_data' referenced before assignment
# something is wrong for item: https://thearmeniankitchen.com/a-hundred-years-and-still-cooking/
# json loads does not work
# Expecting value: line 1 column 1 (char 0)
# cannot decode json
# No value to decode
# local variable 'script_data' referenced before assignment
# something is wrong for item: https://thearmeniankitchen.com/armenian-mixed-vegetable-dolma-recipe/
# scraping - multithreaded, n items:  10
# spider is scraping page: 3
# json loads does not work
# Expecting value: line 1 column 1 (char 0)
# cannot decode json
# No value to decode
# local variable 'script_data' referenced before assignment
# something is wrong for item: https://thearmeniankitchen.com/an-armenian-inspired-menu-for-very/
# json loads does not work
# Expecting value: line 1 column 1 (char 0)
# json loads does not work
# Expecting value: line 1 column 1 (char 0)
# json loads does not work
# Expecting value: line 1 column 1 (char 0)
# cannot decode json
# No value to decode
# local variable 'script_data' referenced before assignment
# something is wrong for item: https://thearmeniankitchen.com/fox-trot-farm-to-table-recipe-and-tour/
# cannot decode json
# No value to decode
# local variable 'script_data' referenced before assignment
# something is wrong for item: https://thearmeniankitchen.com/poached-salmon-with-zucchini-noodles/
# cannot decode json
# No value to decode
# local variable 'script_data' referenced before assignment
# something is wrong for item: https://thearmeniankitchen.com/bamiayov-zahd-okra-stew-recipe-from-ck/
# json loads does not work
# Expecting value: line 1 column 1 (char 0)
# cannot decode json
# No value to decode
# local variable 'script_data' referenced before assignment
# something is wrong for item: https://thearmeniankitchen.com/lentil-potato-patties/
# json loads does not work
# Expecting value: line 1 column 1 (char 0)
# cannot decode json
# No value to decode
# local variable 'script_data' referenced before assignment
# something is wrong for item: https://thearmeniankitchen.com/patligan-eggplant-moussaka-and-armenian/
# json loads does not work
# Expecting value: line 1 column 1 (char 0)
# cannot decode json
# No value to decode
# local variable 'script_data' referenced before assignment
# something is wrong for item: https://thearmeniankitchen.com/its-gouvedge-time-again/
# json loads does not work
# Expecting value: line 1 column 1 (char 0)
# cannot decode json
# No value to decode
# local variable 'script_data' referenced before assignment
# something is wrong for item: https://thearmeniankitchen.com/kufteh-armenian-favorite/
# json loads does not work
# Expecting value: line 1 column 1 (char 0)
# scraping - multithreaded, n items:  10
# json loads does not work
# Expecting value: line 1 column 1 (char 0)
# cannot decode json
# No value to decode
# local variable 'script_data' referenced before assignment
# something is wrong for item: https://thearmeniankitchen.com/chicken-shawarma-with-tahini-yogurt/
# cannot decode json
# No value to decode
# local variable 'script_data' referenced before assignment
# something is wrong for item: https://thearmeniankitchen.com/gluten-free-sheet-pan-lahmajoun-and/
# spider is scraping page: 4
# json loads does not work
# Expecting value: line 1 column 1 (char 0)
# cannot decode json
# No value to decode
# local variable 'script_data' referenced before assignment
# something is wrong for item: https://thearmeniankitchen.com/khorovats-armenian-barbecue/
# json loads does not work
# Expecting value: line 1 column 1 (char 0)
# json loads does not work
# Expecting value: line 1 column 1 (char 0)
# cannot decode json
# No value to decode
# local variable 'script_data' referenced before assignment
# something is wrong for item: https://thearmeniankitchen.com/our-south-carolina-home-blessing/
# cannot decode json
# No value to decode
# local variable 'script_data' referenced before assignment
# something is wrong for item: https://thearmeniankitchen.com/keebah-dikranagerdtsi-delight/
# json loads does not work
# Expecting value: line 1 column 1 (char 0)
# cannot decode json
# No value to decode
# local variable 'script_data' referenced before assignment
# something is wrong for item: https://thearmeniankitchen.com/bulgur-beef-burgers-topped-with/
# json loads does not work
# Expecting value: line 1 column 1 (char 0)
# cannot decode json
# No value to decode
# local variable 'script_data' referenced before assignment
# something is wrong for item: https://thearmeniankitchen.com/orange-pomegranate-lamb-shanks-by/
# json loads does not work
# Expecting value: line 1 column 1 (char 0)
# cannot decode json
# No value to decode
# local variable 'script_data' referenced before assignment
# something is wrong for item: https://thearmeniankitchen.com/lamb-shish-kebab-marinated-in-ararat/
# json loads does not work
# Expecting value: line 1 column 1 (char 0)
# json loads does not work
# Expecting value: line 1 column 1 (char 0)
# cannot decode json
# No value to decode
# local variable 'script_data' referenced before assignment
# cannot decode jsonsomething is wrong for item: https://thearmeniankitchen.com/what-do-anthony-bourdain-and-armenian/
#
# No value to decode
# local variable 'script_data' referenced before assignment
# something is wrong for item: https://thearmeniankitchen.com/my-second-manti-experiment/
# json loads does not work
# Expecting value: line 1 column 1 (char 0)
# cannot decode json
# No value to decode
# local variable 'script_data' referenced before assignment
# something is wrong for item: https://thearmeniankitchen.com/christine-datians-roasted-eggplant-and/
# json loads does not work
# Expecting value: line 1 column 1 (char 0)
# cannot decode json
# No value to decode
# local variable 'script_data' referenced before assignment
# something is wrong for item: https://thearmeniankitchen.com/braised-lamb-shanks-with-vegetables/
# scraping - multithreaded, n items:  10
# spider is scraping page: 5
# json loads does not work
# Expecting value: line 1 column 1 (char 0)
# json loads does not work
# Expecting value: line 1 column 1 (char 0)
# cannot decode json
# No value to decode
# local variable 'script_data' referenced before assignment
# something is wrong for item: https://thearmeniankitchen.com/zucchini-boats-stuffed-with-lamb/
# cannot decode json
# No value to decode
# local variable 'script_data' referenced before assignment
# something is wrong for item: https://thearmeniankitchen.com/baked-mussels-with-herbed-butter/
# json loads does not work
# Expecting value: line 1 column 1 (char 0)
# cannot decode json
# No value to decode
# local variable 'script_data' referenced before assignment
# something is wrong for item: https://thearmeniankitchen.com/tis-season-for-icelandic-lamb/
# json loads does not work
# Expecting value: line 1 column 1 (char 0)
# cannot decode json
# No value to decode
# local variable 'script_data' referenced before assignment
# something is wrong for item: https://thearmeniankitchen.com/crustless-zucchini-pie-armenian-style/
# json loads does not work
# Expecting value: line 1 column 1 (char 0)
# cannot decode json
# No value to decode
# local variable 'script_data' referenced before assignment
# something is wrong for item: https://thearmeniankitchen.com/italian-pork-loin-with-pasta-and/
# json loads does not work
# Expecting value: line 1 column 1 (char 0)
# cannot decode json
# No value to decode
# local variable 'script_data' referenced before assignment
# something is wrong for item: https://thearmeniankitchen.com/lamb-stuffed-baked-eggplant/
# json loads does not work
# Expecting value: line 1 column 1 (char 0)
# cannot decode json
# No value to decode
# local variable 'script_data' referenced before assignment
# something is wrong for item: https://thearmeniankitchen.com/the-debut-of-refurbished-shish-kebab/
# json loads does not work
# Expecting value: line 1 column 1 (char 0)
# cannot decode json
# No value to decode
# local variable 'script_data' referenced before assignment
# something is wrong for item: https://thearmeniankitchen.com/despite-few-set-backs-i-am-on-slow-road/
# json loads does not work
# Expecting value: line 1 column 1 (char 0)
# scraping - multithreaded, n items:  10
# spider is scraping page: 6
# cannot decode json
# No value to decode
# local variable 'script_data' referenced before assignment
# something is wrong for item: https://thearmeniankitchen.com/christine-datian-has-been-long-time/
# json loads does not work
# Expecting value: line 1 column 1 (char 0)
# json loads does not work
# Expecting value: line 1 column 1 (char 0)
# cannot decode json
# No value to decode
# local variable 'script_data' referenced before assignment
# something is wrong for item: https://thearmeniankitchen.com/christine-datians-eggplant-walnut/
# cannot decode json
# No value to decode
# local variable 'script_data' referenced before assignment
# something is wrong for item: https://thearmeniankitchen.com/baked-eggplant-and-spinach-moussaka/
# json loads does not work
# Expecting value: line 1 column 1 (char 0)
# json loads does not work
# Expecting value: line 1 column 1 (char 0)
# cannot decode json
# No value to decode
# local variable 'script_data' referenced before assignment
# something is wrong for item: https://thearmeniankitchen.com/dried-eggplant-skins/
# cannot decode json
# No value to decode
# local variable 'script_data' referenced before assignment
# something is wrong for item: https://thearmeniankitchen.com/sonia-tashjians-basuts-dolma-another/
# json loads does not work
# Expecting value: line 1 column 1 (char 0)
# json loads does not work
# Expecting value: line 1 column 1 (char 0)
# cannot decode json
# No value to decode
# local variable 'script_data' referenced before assignment
# something is wrong for item: https://thearmeniankitchen.com/dougs-easy-kebab-recipe/
# cannot decode json
# No value to decode
# local variable 'script_data' referenced before assignment
# something is wrong for item: https://thearmeniankitchen.com/cant-get-enough-lahmajoun/
# json loads does not work
# Expecting value: line 1 column 1 (char 0)
# cannot decode json
# No value to decode
# local variable 'script_data' referenced before assignment
# something is wrong for item: https://thearmeniankitchen.com/spicy-middle-eastern-meat-pies/
# json loads does not work
# Expecting value: line 1 column 1 (char 0)
# cannot decode json
# No value to decode
# local variable 'script_data' referenced before assignment
# something is wrong for item: https://thearmeniankitchen.com/hajimoms-dzedzadzs-meat-and-wheat/
# json loads does not work
# Expecting value: line 1 column 1 (char 0)
# cannot decode json
# No value to decode
# scraping - multithreaded, n items:  10
# local variable 'script_data' referenced before assignment
# something is wrong for item: https://thearmeniankitchen.com/making-dolma-using-dried-eggplant-skins/
# spider is scraping page: 7
# json loads does not work
# Expecting value: line 1 column 1 (char 0)
# json loads does not work
# Expecting value: line 1 column 1 (char 0)
# json loads does not work
# Expecting value: line 1 column 1 (char 0)
# cannot decode json
# No value to decode
# local variable 'script_data' referenced before assignment
# something is wrong for item: https://thearmeniankitchen.com/cruise-food/
# cannot decode json
# No value to decode
# local variable 'script_data' referenced before assignment
# something is wrong for item: https://thearmeniankitchen.com/baked-fish-armenian-style/
# cannot decode json
# No value to decode
# local variable 'script_data' referenced before assignment
# something is wrong for item: https://thearmeniankitchen.com/coriander-crusted-fish-with-chickpea/
# json loads does not work
# Expecting value: line 1 column 1 (char 0)
# json loads does not work
# Expecting value: line 1 column 1 (char 0)
# cannot decode json
# No value to decode
# local variable 'script_data' referenced before assignment
# something is wrong for item: https://thearmeniankitchen.com/reader-feature-chrsitine-datians/
# cannot decode json
# No value to decode
# local variable 'script_data' referenced before assignment
# something is wrong for item: https://thearmeniankitchen.com/mango-season-is-here-in-florida-that-is/
# json loads does not work
# Expecting value: line 1 column 1 (char 0)
# cannot decode json
# No value to decode
# local variable 'script_data' referenced before assignment
# something is wrong for item: https://thearmeniankitchen.com/todays-lesson-soujouk/
# json loads does not work
# Expecting value: line 1 column 1 (char 0)
# cannot decode json
# No value to decode
# local variable 'script_data' referenced before assignment
# something is wrong for item: https://thearmeniankitchen.com/ground-chicken-lule-kebab/
# json loads does not work
# Expecting value: line 1 column 1 (char 0)
# cannot decode json
# No value to decode
# local variable 'script_data' referenced before assignment
# something is wrong for item: https://thearmeniankitchen.com/christine-datians-grilled-chicken-and/
# json loads does not work
# Expecting value: line 1 column 1 (char 0)
# cannot decode json
# No value to decode
# local variable 'script_data' referenced before assignment
# something is wrong for item: https://thearmeniankitchen.com

# json loads does not work
# Expecting value: line 1 column 1 (char 0)
# cannot decode json
# No value to decode
# local variable 'script_data' referenced before assignment
# something is wrong for item: https://thearmeniankitchen.com/bolsetsi-kuftehor-is-it/
# json loads does not work
# Expecting value: line 1 column 1 (char 0)
# cannot decode json
# No value to decode
# local variable 'script_data' referenced before assignment
# something is wrong for item: https://thearmeniankitchen.com/stovetop-lamb-roast-sunday-dinner-any/
# json loads does not work
# Expecting value: line 1 column 1 (char 0)
# cannot decode json
# No value to decode
# local variable 'script_data' referenced before assignment
# something is wrong for item: https://thearmeniankitchen.com/dolma-deconstructed/
# json loads does not work
# Expecting value: line 1 column 1 (char 0)
# cannot decode json
# No value to decode
# local variable 'script_data' referenced before assignment
# something is wrong for item: https://thearmeniankitchen.com/theres-nothing-fishy-about-armenian/
# json loads does not work
# Expecting value: line 1 column 1 (char 0)
# cannot decode json
# No value to decode
# local variable 'script_data' referenced before assignment
# something is wrong for item: https://thearmeniankitchen.com/okra-is-not-armenian-talk-show-host/
# json loads does not work
# Expecting value: line 1 column 1 (char 0)
# cannot decode json
# No value to decode
# local variable 'script_data' referenced before assignment
# something is wrong for item: https://thearmeniankitchen.com/sud-keeba/
# scraping - multithreaded, n items:  10
# spider is scraping page: 16
# json loads does not work
# Expecting value: line 1 column 1 (char 0)
# cannot decode json
# No value to decode
# local variable 'script_data' referenced before assignment
# something is wrong for item: https://thearmeniankitchen.com/why-bash-anyone-elses-food-lets-just/
# json loads does not work
# Expecting value: line 1 column 1 (char 0)
# cannot decode json
# No value to decode
# local variable 'script_data' referenced before assignment
# something is wrong for item: https://thearmeniankitchen.com/gouvedge-lamb-veggies-and-memories/
# json loads does not work
# Expecting value: line 1 column 1 (char 0)
# cannot decode json
# No value to decode
# local variable 'script_data' referenced before assignment
# something is wrong for item: https://thearmeniankitchen.com/pork-other-armenian-meat/
# json loads does not work
# Expecting value: line 1 column 1 (char 0)
# cannot decode json
# No value to decode
# local variable 'script_data' referenced before assignment
# something is wrong for item: https://thearmeniankitchen.com/best-lamb-video-youll-never-see/
# json loads does not work
# Expecting value: line 1 column 1 (char 0)
# cannot decode json
# No value to decode
# local variable 'script_data' referenced before assignment
# something is wrong for item: https://thearmeniankitchen.com/armenian-food-in-america-is-old-news/
# json loads does not work
# Expecting value: line 1 column 1 (char 0)
# cannot decode json
# No value to decode
# local variable 'script_data' referenced before assignment
# something is wrong for item: https://thearmeniankitchen.com/heart-healthy-fish-recipe-fish-plaki/
# json loads does not work
# Expecting value: line 1 column 1 (char 0)
# cannot decode json
# No value to decode
# local variable 'script_data' referenced before assignment
# something is wrong for item: https://thearmeniankitchen.com/heart-healthy-kufteh-with-video/
# json loads does not work
# Expecting value: line 1 column 1 (char 0)
# scraping - multithreaded, n items:  10
# spider is scraping page: 17
# json loads does not work
# Expecting value: line 1 column 1 (char 0)
# cannot decode json
# No value to decode
# local variable 'script_data' referenced before assignment
# something is wrong for item: https://thearmeniankitchen.com/wrapping-up-healthier-armenian-dinner/
# cannot decode json
# No value to decode
# local variable 'script_data' referenced before assignment
# something is wrong for item: https://thearmeniankitchen.com/pom-reading/
# json loads does not work
# Expecting value: line 1 column 1 (char 0)
# cannot decode json
# No value to decode
# local variable 'script_data' referenced before assignment
# something is wrong for item: https://thearmeniankitchen.com/armenian-leftovers-eggs-lamb/
# json loads does not work
# Expecting value: line 1 column 1 (char 0)
# cannot decode json
# No value to decode
# local variable 'script_data' referenced before assignment
# something is wrong for item: https://thearmeniankitchen.com/hamburger-or-lamb-burger-no-contest/
# scraping - multithreaded, n items:  4
# spider is scraping page: 18
# Cannot open the menu url, status code = 404, url= https://thearmeniankitchen.com/category/main-dishes/page/18
# spider is scraping page: 1
# json loads does not work
# Expecting value: line 1 column 1 (char 0)
# cannot decode json
# No value to decode
# local variable 'script_data' referenced before assignment
# something is wrong for item: https://thearmeniankitchen.com/lentil-soup-with-meatballs/
# json loads does not work
# Expecting value: line 1 column 1 (char 0)
# json loads does not work
# Expecting value: line 1 column 1 (char 0)
# cannot decode json
# No value to decodecannot decode json
#
# No value to decode
# local variable 'script_data' referenced before assignment
# local variable 'script_data' referenced before assignment
# something is wrong for item: https://thearmeniankitchen.com/happy-new-year-and-merry-armenian/something is wrong for item: https://thearmeniankitchen.com/endless-possibilities-with-leftover/
#
# scraping - multithreaded, n items:  10
# spider is scraping page: 2
# json loads does not work
# Expecting value: line 1 column 1 (char 0)
# cannot decode json
# No value to decode
# local variable 'script_data' referenced before assignment
# something is wrong for item: https://thearmeniankitchen.com/armenian-chicken-rice-and-lemon-soup/
# json loads does not work
# Expecting value: line 1 column 1 (char 0)
# json loads does not work
# Expecting value: line 1 column 1 (char 0)
# json loads does not work
# Expecting value: line 1 column 1 (char 0)
# json loads does not work
# Expecting value: line 1 column 1 (char 0)
# json loads does not work
# Expecting value: line 1 column 1 (char 0)
# cannot decode json
# No value to decode
# local variable 'script_data' referenced before assignment
# something is wrong for item: https://thearmeniankitchen.com/stay-cool-with-chilled-yogurt-based/
# json loads does not work
# Expecting value: line 1 column 1 (char 0)cannot decode json
#
# No value to decode
# local variable 'script_data' referenced before assignment
# something is wrong for item: https://thearmeniankitchen.com/lemon-chicken-spinach-soup-with-mint-by/
# cannot decode json
# No value to decode
# local variable 'script_data' referenced before assignment
# something is wrong for item: https://thearmeniankitchen.com/garbanzo-bean-and-vegetable-soup-by/
# cannot decode json
# No value to decode
# local variable 'script_data' referenced before assignment
# something is wrong for item: https://thearmeniankitchen.com/armenian-madzoon-abour-yogurt-soup/
# cannot decode json
# No value to decode
# local variable 'script_data' referenced before assignment
# something is wrong for item: https://thearmeniankitchen.com/patligan-eggplant-moussaka-and-armenian/
# cannot decode json
# No value to decode
# local variable 'script_data' referenced before assignment
# something is wrong for item: https://thearmeniankitchen.com/sonia-tashjians-comfort-soup-nunik-abur/
# json loads does not work
# Expecting value: line 1 column 1 (char 0)
# cannot decode json
# No value to decode
# local variable 'script_data' referenced before assignment
# something is wrong for item: https://thearmeniankitchen.com/keep-dad-cool-this-fathers-day-with/
# json loads does not work
# Expecting value: line 1 column 1 (char 0)
# cannot decode json
# No value to decode
# local variable 'script_data' referenced before assignment
# something is wrong for item: https://thearmeniankitchen.com/broccoli-parmesan-yogurt-soup/
# json loads does not work
# Expecting value: line 1 column 1 (char 0)
# cannot decode json
# No value to decode
# local variable 'script_data' referenced before assignment
# something is wrong for item: https://thearmeniankitchen.com/christine-vartanian-datians-eggplant/
# scraping - multithreaded, n items:  10
# spider is scraping page: 3
# json loads does not work
# Expecting value: line 1 column 1 (char 0)
# cannot decode json
# No value to decode
# local variable 'script_data' referenced before assignment
# something is wrong for item: https://thearmeniankitchen.com/white-bean-spinach-and-garlic-soup-from/
# json loads does not work
# Expecting value: line 1 column 1 (char 0)
# cannot decode json
# No value to decode
# local variable 'script_data' referenced before assignment
# something is wrong for item: https://thearmeniankitchen.com/armenian-tomato-and-bulgur-soup-by/
# json loads does not work
# Expecting value: line 1 column 1 (char 0)
# json loads does not work
# Expecting value: line 1 column 1 (char 0)
# cannot decode json
# No value to decode
# local variable 'script_data' referenced before assignment
# something is wrong for item: https://thearmeniankitchen.com/with-kalajian-family-wedding-right/
# json loads does not work
# Expecting value: line 1 column 1 (char 0)
# cannot decode json
# No value to decode
# local variable 'script_data' referenced before assignment
# something is wrong for item: https://thearmeniankitchen.com/spinach-sorrel-and-rice-soup/
# cannot decode json
# No value to decode
# local variable 'script_data' referenced before assignment
# something is wrong for item: https://thearmeniankitchen.com/christine-datians-armenian-tomato-and/
# json loads does not work
# Expecting value: line 1 column 1 (char 0)
# cannot decode json
# No value to decode
# local variable 'script_data' referenced before assignment
# something is wrong for item: https://thearmeniankitchen.com/kale-and-pearl-barley-soup/
# json loads does not work
# Expecting value: line 1 column 1 (char 0)
# cannot decode json
# No value to decode
# local variable 'script_data' referenced before assignment
# something is wrong for item: https://thearmeniankitchen.com/red-pepper-white-bean-and-feta-soup/
# json loads does not work
# Expecting value: line 1 column 1 (char 0)
# json loads does not work
# Expecting value: line 1 column 1 (char 0)
# cannot decode json
# No value to decode
# local variable 'script_data' referenced before assignment
# something is wrong for item: https://thearmeniankitchen.com/christine-vartanian-datian-serves-up/
# scraping - multithreaded, n items:  10
# spider is scraping page: 4
# cannot decode json
# No value to decode
# local variable 'script_data' referenced before assignment
# something is wrong for item: https://thearmeniankitchen.com/beans-leaf-soup-two-suggested-recipes/
# json loads does not work
# Expecting value: line 1 column 1 (char 0)
# cannot decode json
# No value to decode
# local variable 'script_data' referenced before assignment
# something is wrong for item: https://thearmeniankitchen.com/chilled-chickpea-and-tahini-soup/
# json loads does not work
# Expecting value: line 1 column 1 (char 0)
# cannot decode json
# No value to decode
# local variable 'script_data' referenced before assignment
# something is wrong for item: https://thearmeniankitchen.com/a-taste-of-wild-side-out-of-yerevan-and/
# json loads does not work
# Expecting value: line 1 column 1 (char 0)
# cannot decode json
# No value to decode
# local variable 'script_data' referenced before assignment
# something is wrong for item: https://thearmeniankitchen.com/aveluk-wild-sorrel-uniquely-armenian/
# json loads does not work
# Expecting value: line 1 column 1 (char 0)
# cannot decode json
# No value to decode
# local variable 'script_data' referenced before assignment
# something is wrong for item: https://thearmeniankitchen.com/spas-madzoon-yogurt-soup-with-grains/
# json loads does not work
# Expecting value: line 1 column 1 (char 0)
# cannot decode json
# No value to decode
# local variable 'script_data' referenced before assignment
# something is wrong for item: https://thearmeniankitchen.com/christine-datians-mashed-potato-and/
# json loads does not work
# Expecting value: line 1 column 1 (char 0)
# cannot decode json
# No value to decode
# local variable 'script_data' referenced before assignment
# something is wrong for item: https://thearmeniankitchen.com/winter-red-lentil-soup-with-browned/
# json loads does not work
# Expecting value: line 1 column 1 (char 0)
# cannot decode json
# No value to decode
# local variable 'script_data' referenced before assignment
# something is wrong for item: https://thearmeniankitchen.com/two-soup-recipes-from-sonia-tashjian/
# json loads does not work
# Expecting value: line 1 column 1 (char 0)
# cannot decode json
# No value to decode
# local variable 'script_data' referenced before assignment
# something is wrong for item: https://thearmeniankitchen.com/looking-for-hearty-soup-to-serve-this/
# json loads does not work
# Expecting value: line 1 column 1 (char 0)
# cannot decode json
# No value to decode
# local variable 'script_data' referenced before assignment
# something is wrong for item: https://thearmeniankitchen.com/cucumber-avocado-yogurt-soup_80/
# json loads does not work
# Expecting value: line 1 column 1 (char 0)
# cannot decode json
# No value to decode
# local variable 'script_data' referenced before assignment
# something is wrong for item: https://thearmeniankitchen.com/easy-creamy-white-bean-soup/
# scraping - multithreaded, n items:  10
# spider is scraping page: 5
# json loads does not work
# Expecting value: line 1 column 1 (char 0)
# cannot decode json
# No value to decode
# local variable 'script_data' referenced before assignment
# something is wrong for item: https://thearmeniankitchen.com/reader-feature-alice-vartanians-easy/
# json loads does not work
# Expecting value: line 1 column 1 (char 0)
# json loads does not work
# Expecting value: line 1 column 1 (char 0)
# cannot decode json
# No value to decode
# local variable 'script_data' referenced before assignment
# something is wrong for item: https://thearmeniankitchen.com/ttvebas-holy-maundy-thursday-armenian/
# cannot decode json
# No value to decode
# local variable 'script_data' referenced before assignment
# something is wrong for item: https://thearmeniankitchen.com/its-pumpkin-time/
# json loads does not work
# Expecting value: line 1 column 1 (char 0)
# cannot decode json
# No value to decode
# local variable 'script_data' referenced before assignment
# something is wrong for item: https://thearmeniankitchen.com/tarkhanabour-specialty-soup-recipe-from/
# json loads does not work
# Expecting value: line 1 column 1 (char 0)
# json loads does not work
# Expecting value: line 1 column 1 (char 0)
# cannot decode jsoncannot decode json
#
# No value to decodeNo value to decode
#
# local variable 'script_data' referenced before assignmentlocal variable 'script_data' referenced before assignment
#
# something is wrong for item: https://thearmeniankitchen.com/agenchik-soup-specialty-from-musa-dagh/
# something is wrong for item: https://thearmeniankitchen.com/basil-armenian-church-and-zesty/
# json loads does not work
# Expecting value: line 1 column 1 (char 0)
# cannot decode json
# No value to decode
# local variable 'script_data' referenced before assignment
# something is wrong for item: https://thearmeniankitchen.com

# json loads does not work
# Expecting value: line 1 column 1 (char 0)
# cannot decode json
# No value to decode
# local variable 'script_data' referenced before assignment
# something is wrong for item: https://thearmeniankitchen.com/vospov-kufteh-red-lentils-with-bulgur/
# json loads does not work
# Expecting value: line 1 column 1 (char 0)
# cannot decode json
# No value to decode
# local variable 'script_data' referenced before assignment
# something is wrong for item: https://thearmeniankitchen.com/basil/
# json loads does not work
# Expecting value: line 1 column 1 (char 0)
# cannot decode json
# No value to decode
# local variable 'script_data' referenced before assignment
# something is wrong for item: https://thearmeniankitchen.com/meatless-imam-bayeldi-or-baylee-baghlee/
# json loads does not work
# Expecting value: line 1 column 1 (char 0)
# cannot decode json
# No value to decode
# local variable 'script_data' referenced before assignment
# something is wrong for item: https://thearmeniankitchen.com/vegetable-stuffed-zucchini-boats/
# json loads does not work
# Expecting value: line 1 column 1 (char 0)
# cannot decode json
# No value to decode
# local variable 'script_data' referenced before assignment
# something is wrong for item: https://thearmeniankitchen.com/preparing-for-lent/
# json loads does not work
# Expecting value: line 1 column 1 (char 0)
# json loads does not work
# Expecting value: line 1 column 1 (char 0)
# cannot decode json
# No value to decode
# local variable 'script_data' referenced before assignment
# something is wrong for item: https://thearmeniankitchen.com/topig-very-special-lenten-appetizer/
# cannot decode json
# No value to decode
# local variable 'script_data' referenced before assignment
# something is wrong for item: https://thearmeniankitchen.com/fool-ful-fuul-fava-bean-stew/
# scraping - multithreaded, n items:  10
# spider is scraping page: 9
# Cannot open the menu url, status code = 404, url= https://thearmeniankitchen.com/category/meatless-lenten-dishes/page/9

# %%
len(result_list)
# Out:
# 932

# %%
copy_result_list = result_list.copy()

# %%
res_df = pd.DataFrame(copy_result_list)

# %%
res_df
# Out:
#                           name total_time  \
# 0          Lamb Shank Gouvedge     PT945M
# 1                   Losh Kebab      PT35M
# 2    Zucchini, Fassoulia-style      PT57M
# 3                  Kadin Boudi      PT48M
# 4             Pumpkin Geragoor      PT80M
# ..                         ...        ...
# 927
# 928                      Plaki      PT45M
# 929
# 930
# 931
#
#                                            ingredients  \
# 0    [4 large lamb shanks (trimmed of fat), lamb br...
# 1    [1¼ lbs. ground lamb (Ground beef may be subst...
# 2    [1 lb. ground meat (We used 93% lean ground tu...
# 3    [1 lb. ground lamb (I used locally sourced lam...
# 4    [2 small pie pumpkins, 1 ½ lb ground beef (unc...
# ..                                                 ...
# 927
# 928  [2 carrots (peeled and diced), 2 stalks celery...
# 929
# 930
# 931
#
#                                           instructions           servings  \
# 0    [Place the trimmed lamb shanks in a large pot ...    [6, 6 servings]
# 1    [In a small mixing bowl, combine the beaten eg...                [4]
# 2    [Coat the bottom of a large pot with 2 Tbsp. o...                [4]
# 3    [Combine meat, rice, onions and cheese, then p...  [8, 8 croquettes]
# 4    [Carefully cut pumpkins in half.  Place 2 pump...    [6, 6 servings]
# ..                                                 ...                ...
# 927
# 928  [Blend the tomato paste with about 2 cups of w...    [6, 6 servings]
# 929
# 930
# 931
#
#                                 category prep_time cook_time
# 0                          [Main Course]    PT120M    PT105M
# 1                          [Main Course]     PT20M     PT15M
# 2                          [Main Course]     PT15M     PT45M
# 3                          [Main Course]     PT30M     PT18M
# 4                                   None     PT20M     PT60M
# ..                                   ...       ...       ...
# 927
# 928  [Appetizer, Main Course, Side Dish]     PT15M     PT30M
# 929
# 930
# 931
#
# [932 rows x 8 columns]

# %%
nan_value = float("NaN")

# %%
res_df.replace("", nan_value, inplace=True)

# %%
res_df.tail()
# Out:
#       name total_time                                        ingredients  \
# 927    NaN        NaN                                                NaN
# 928  Plaki      PT45M  [2 carrots (peeled and diced), 2 stalks celery...
# 929    NaN        NaN                                                NaN
# 930    NaN        NaN                                                NaN
# 931    NaN        NaN                                                NaN
#
#                                           instructions         servings  \
# 927                                                NaN              NaN
# 928  [Blend the tomato paste with about 2 cups of w...  [6, 6 servings]
# 929                                                NaN              NaN
# 930                                                NaN              NaN
# 931                                                NaN              NaN
#
#                                 category prep_time cook_time
# 927                                  NaN       NaN       NaN
# 928  [Appetizer, Main Course, Side Dish]     PT15M     PT30M
# 929                                  NaN       NaN       NaN
# 930                                  NaN       NaN       NaN
# 931                                  NaN       NaN       NaN

# %%
res_df.dropna(subset=['name'], inplace=True)

# %%
res_df
# Out:
#                                                 name total_time  \
# 0                                Lamb Shank Gouvedge     PT945M
# 1                                         Losh Kebab      PT35M
# 2                          Zucchini, Fassoulia-style      PT57M
# 3                                        Kadin Boudi      PT48M
# 4                                   Pumpkin Geragoor      PT80M
# ..                                               ...        ...
# 905  Helen Der Aprahamian's (Modified) Eech Recipe        PT45M
# 906                                    Topik (Topig)      PT50M
# 910                                      Tahini Hatz     PT200M
# 916                   Potato-Green Bean Bulgur Pilaf       None
# 928                                            Plaki      PT45M
#
#                                            ingredients  \
# 0    [4 large lamb shanks (trimmed of fat), lamb br...
# 1    [1¼ lbs. ground lamb (Ground beef may be subst...
# 2    [1 lb. ground meat (We used 93% lean ground tu...
# 3    [1 lb. ground lamb (I used locally sourced lam...
# 4    [2 small pie pumpkins, 1 ½ lb ground beef (unc...
# ..                                                 ...
# 905  [¼ cup olive oil, 1 large onion (finely choppe...
# 906  [16 oz chickpeas (1 large can, drained, rinsed...
# 910  [1 package dry granular yeast , 1 tsp sugar, ¼...
# 916  [1 cup green beans (trimmed and cut into ½ inc...
# 928  [2 carrots (peeled and diced), 2 stalks celery...
#
#                                           instructions  \
# 0    [Place the trimmed lamb shanks in a large pot ...
# 1    [In a small mixing bowl, combine the beaten eg...
# 2    [Coat the bottom of a large pot with 2 Tbsp. o...
# 3    [Combine meat, rice, onions and cheese, then p...
# 4    [Carefully cut pumpkins in half.  Place 2 pump...
# ..                                                 ...
# 905  [Sauté onion and pepper in olive oil until sof...
# 906  [Saute the onions in hot oil in a skillet unti...
# 910  [Place the yeast and sugar in a large mixing b...
# 916  [In a microwave-safe bowl, cook cut green bean...
# 928  [Blend the tomato paste with about 2 cups of w...
#
#                     servings                             category prep_time  \
# 0            [6, 6 servings]                        [Main Course]    PT120M
# 1                        [4]                        [Main Course]     PT20M
# 2                        [4]                        [Main Course]     PT15M
# 3          [8, 8 croquettes]                        [Main Course]     PT30M
# 4            [6, 6 servings]                                 None     PT20M
# ..                       ...                                  ...       ...
# 905                     None        [Appetizer, Salad, Side Dish]     PT30M
# 906          [21, 21 pieces]             [Appetizer, Main Course]     PT40M
# 910  [6, 6 5" spiral breads]                            [Dessert]     PT30M
# 916          [6, 6 servings]                                 None     PT15M
# 928          [6, 6 servings]  [Appetizer, Main Course, Side Dish]     PT15M
#
#     cook_time
# 0      PT105M
# 1       PT15M
# 2       PT45M
# 3       PT18M
# 4       PT60M
# ..        ...
# 905     PT15M
# 906     PT10M
# 910     PT20M
# 916     PT35M
# 928     PT30M
#
# [153 rows x 8 columns]

# %%
res_df.to_csv('data/armenia/armeniankitchen.csv')
