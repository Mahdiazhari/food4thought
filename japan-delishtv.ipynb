# %%
import pandas as pd
import json
import requests
import random
from lxml import html
import re
import time

from  util.spider import Spider
from util.http_utility import get_http_headers
from util.user_agent import get_random_ua

# %% [markdown]
# # Scrape Japan - Delishtv

# %% [markdown]
# https://delishkitchen.tv/

# %%
class DelishKitchen(Spider): #inherit Spider Class
    """This class extends the main Spider Class for Scraping Delish TV recipe website.

    Args:
        Spider (_type_): _description_
    """

    def __init__(self, main_page, seeds, listing, attrs, header=None):
        super().__init__(main_page,seeds,listing,attrs, header)

    #Process the duration format from the recipes website
    def process_time(self,time_str):
        if 'S' in time_str:
            #hours = time_str.split("H")[0]
            seconds  = time_str.split("PT")[1].split('S')[0]
            #minutes = re.findall(r'\b\d+\b', time_str.split("H")[1])
            # print(hours)
            # print(minutes)
            return seconds
        else:
            return time_str
    
    # def check_normalize_space(self,xpath):
    #     super().check_normalize_space(xpath)

    def scrape_one_item(self,url):
        """To scrape one item from a given url.

        Args:
            url (str): url of the item

        Returns:
            dict: dict of the item
        """
        session = requests.Session() 
        session.headers.update(self.header)

        #add home page url to the obtained item url if item url is not complete
        if self.main_page not in url:
            res = session.get(self.main_page + url)
        else:
            res = session.get(url)

        if res.status_code == 200:
            try:
                #print(res.status_code)
                doc = html.document_fromstring(res.text)
                #set default values for variables
                name, total_time, ingredients, instructions, servings, category, prep_time, cook_time = '','','','','','','',''

                doc = html.document_fromstring(res.text)
                
                #get data from script application json with recipeIngredient
                script_data = json.loads(doc.xpath("normalize-space(//script[@type='application/ld+json'][contains(text(), 'recipeIngredient')])"))
                #print(script_data)

                name = script_data.get('name')

                ingredients = script_data.get('recipeIngredient')
                ingredients = ' '.join(ingredients)# join ingredients

                instructions = []
                inst_list_web = script_data.get('recipeInstructions')

                for instruction in inst_list_web:
                    instructions.append(instruction['text'])
                instructions= ' '.join(instructions) #join all as one


                servings = script_data.get('recipeYield')

                category = doc.xpath('normalize-space(//ul[@class="categories"])')


                total_time = script_data.get('totalTime')
                total_time = self.process_time(total_time)
                
                #for this website the cooktime and preptime are misleading
        
                #cook_time = script_data.get('cookTime')
                #prep_time = script_data.get('prepTime')

                return {'name': name, 'total_time': total_time, 'ingredients': ingredients, 'instructions': instructions, 'servings': servings,
                'category': category, 'prep_time': prep_time, 'cook_time': cook_time,}
            except Exception as e:
                raise Exception('something is wrong for item: {}'.format(url)) from e


        else:
            raise Exception('Cannot open one menu url, status code = {}'.format(res.status_code))
    

    def get_items_from_page(self, page_url):
        """Get all item urls from the current page listing

        Args:
            page_url (str): url of the page

        Returns:
           list: list containing the url of items in the current page
        """
        session = requests.Session() 
        session.headers.update(self.header)
        res = session.get(page_url)
        if res.status_code == 200:
            doc = html.document_fromstring(res.text)
            urls = doc.xpath(self.listing['items'])
            print('got items from url: ', page_url)
            return urls
        else:
            raise Exception('Cannot open the menu url, status code = {}'.format(res.status_code))

# %%
listing={'items': '//ul[@class="columns with-max-three"]//div[contains(@class,"delish-renewal-recipe-item-card")]//a/@href', 'next': { 'next_page_str': '?page={}', 'type': 'url'}}
seeds = ['https://delishkitchen.tv/categories/19878', 'https://delishkitchen.tv/categories/655', 'https://delishkitchen.tv/categories/17359', ]

# %%
delishtv_spider= DelishKitchen('https://delishkitchen.tv', seeds= seeds, listing =listing,attrs= '')

# %%
delishtv_spider.scrape_one_item('https://delishkitchen.tv/recipes/216142397518644383')
# Out:
# {'name': '冷凍餃子を使ってお手軽に♪ ニラもやしの餃子鍋',
#  'total_time': '1200',
#  'ingredients': '冷凍餃子 12個 豆もやし 1袋 ニラ 1/2束 しめじ 1パック 酒 大さじ1 塩 小さじ1/3 鶏ガラスープの素 小さじ1/2 おろしにんにく 小さじ1 おろししょうが 小さじ1 水 300cc 唐辛子(輪切り) 少々 ポン酢しょうゆ 大さじ2 ラー油 適量',
#  'instructions': 'ニラは3cm幅に切る。しめじは根元を切り落とし、小房に分ける。 ボウルに豆もやし、ニラ、しめじを入れて混ぜる。 別のボウルに☆を入れて混ぜる(鍋スープ)。 鍋に半量の2を敷き詰め、餃子は鍋に沿うように並べ入れて、中央に残りの2をのせる。鍋スープをまわしかけ、中火に熱し、煮立ったらふたをして5分程煮る。 4にポン酢しょうゆ、ラー油を添える。',
#  'servings': '2人分',
#  'category': 'その他の鍋料理',
#  'prep_time': '',
#  'cook_time': ''}

# %%
result_list = delishtv_spider.start_scrape(max_pages=1) #max page is only 130
# Out:
# spider is scraping page: 1
# spider is scraping url:  https://delishkitchen.tv/categories/19878?page=1
# got items from url:  https://delishkitchen.tv/categories/19878?page=1
# scraping - multithreaded, n items:  30

# %%
result_list
# Out:
# [{'name': 'レンジでできる！ 豚バラもやしのバターポン酢',
#   'total_time': '600',
#   'ingredients': '豚バラ薄切り肉 150g もやし 1袋(200g) 酒 大さじ1 有塩バター 大さじ1 ポン酢しょうゆ 大さじ2 かつお節 1パック 七味唐辛子 適量 細ねぎ（刻み） 適量',
#   'instructions': '豚肉は食べやすい大きさに切る。耐熱容器にもやしを入れ、かつお節を振り入れ、その上に切った豚肉を広げてのせる 酒を全体に振りかけてバターをところどころに乗せ、ふんわりラップをして600Wのレンジで5～6分加熱する。 豚肉に火が通ったらポン酢しょうゆを全体を混ぜる。器に盛り、七味唐辛子をふって刻んだ細ねぎを乗せて完成！',
#   'servings': '2人分',
#   'category': 'その他の野菜料理豚肉豚バラ薄切り肉よく使う野菜',
#   'prep_time': '',
#   'cook_time': ''},
#  {'name': '甘い味噌味が食欲そそる！ 豚じゃが味噌炒め',
#   'total_time': '900',
#   'ingredients': 'じゃがいも 1個 豚こま切れ肉 70g ごま油 大さじ1/2 ネギ 適量 白ごま 適量 酒 小さじ1 片栗粉 小さじ1 味噌 小さじ1 酒 小さじ1 砂糖 小さじ2 みりん 小さじ1',
#   'instructions': '皮ごとよく洗ったじゃがいもを500wのレンジで5分加熱する \n粗熱が取れたら一口大に切る 豚肉に酒、片栗粉を揉み込む フライパンにごま油を熱し、肉を焼いていく \n焼き色がついてきたらじゃがいもを加える 味噌、砂糖、酒、みりんをよく混ぜて加え、全体にからませる \n仕上げにネギ、ごまを散らして完成！',
#   'servings': '1人分',
#   'category': '煮物(野菜)肉じゃが秋冬の旬野菜ねぎ',
#   'prep_time': '',
#   'cook_time': ''},
#  {'name': '時短がっつりおかず！ チーズ焼き卵巾着',
#   'total_time': '900',
#   'ingredients': '油揚げ 1枚 卵 2個 スライスチーズ 1枚 サラダ油 小さじ2 酒 大さじ1 みりん 大さじ2 しょうゆ 大さじ2 砂糖 大さじ1',
#   'instructions': '油揚げを半分に切り、袋状に開いて内側をひっくり返す。 1に半分に切って小さく折りたたんだスライスチーズを入れ、卵を1個ずつ割り入れる。つまようじで口をとめる。 フライパンにサラダ油を入れて熱し、2を並べる。弱火で5分程度焼いたらひっくり返し、もう片面も同様に焼く。 3に☆を加えて煮からめる。',
#   'servings': '2人分',
#   'category': 'その他の卵料理豆類大豆加工品油揚げ',
#   'prep_time': '',
#   'cook_time': ''},
#  {'name': '定番の一品！ ほうれん草のごま和え',
#   'total_time': '300',
#   'ingredients': 'ほうれん草 1袋(200g) 白すりごま 大さじ3 砂糖 小さじ2 しょうゆ 小さじ2 和風顆粒だし 小さじ1',
#   'instructions': 'ほうれん草は洗い、ラップにしっかりと包んで600Wのレンジで1分30秒〜40秒程加熱し、水にさらしておく。 水気を切ったほうれん草の根元を切り落とし、食べやすい大きさに切る。 ボウルに白すりごま、☆を入れて混ぜ、ほうれん草を加えてあえる。',
#   'servings': '2人前',
#   'category': '蒸し物・お浸し(野菜)お浸し秋冬の旬野菜ほうれん草',
#   'prep_time': '',
#   'cook_time': ''},
#  {'name': '丸めず簡単！ レンチン豆腐ハンバーグ',
#   'total_time': '900',
#   'ingredients': '合挽き肉 100g 絹豆腐 150g コンソメ 小さじ1 ケチャップ 大さじ1 中濃ソース 大さじ1 サラダ油 小さじ1 塩こしょう 少々 ピザ用チーズ 適量 卵 1個 パセリ[乾燥] 少々',
#   'instructions': 'ボウルに豆腐、合びき肉、コンソメ、ケチャップ、ソース、サラダ油、塩こしょうを加えて混ぜる。耐熱皿に入れてならし、ピザ用チーズをちらす。 ラップをせずに、600Wのレンジで7〜8分加熱する。 中央に温泉卵をのせて、パセリをちらす。',
#   'servings': '2人分',
#   'category': '焼き物(肉)ハンバーグ豆類大豆加工品',
#   'prep_time': '',
#   'cook_time': ''},
#  {'name': '味付けバッチリ！ なすとひき肉の甘辛炒め',
#   'total_time': '600',
#   'ingredients': 'なす 3本 鶏ひき肉 150g 細ねぎ（刻み） 適量 サラダ油(なす用) 大さじ3 サラダ油(肉用) 小さじ1 酒 大さじ1 砂糖 小さじ1 しょうゆ 大さじ1 みりん 大さじ1',
#   'instructions': 'なすは食べやすい大きさに切る。フライパンにサラダ油を熱し、なすを入れ柔らかくなるまで中火で炒め、取り出す。 フライパンにサラダ油を入れて熱し鶏ひき肉を入れて中火で炒め、肉の色が変わったらなすを戻す。 ☆の調味料を加えて炒め合わせる。器に盛り付けて、細ねぎを散らして完成。',
#   'servings': '2人分',
#   'category': '炒め物(野菜)その他の炒め物（野菜）夏の旬野菜なす',
#   'prep_time': '',
#   'cook_time': ''},
#  {'name': 'パパッと簡単絶品♪ ツナ玉ねぎの卵とじ丼',
#   'total_time': '600',
#   'ingredients': 'ごはん どんぶり1杯(200g) ツナ缶[オイル漬け] 1缶(70g) 溶き卵 2個分 玉ねぎ 1/2個 かいわれ 適量 水 100cc しょうゆ 小さじ4 和風顆粒だし ひとつまみ',
#   'instructions': '玉ねぎは薄切りにする。 フライパンにツナ缶を缶汁ごと入れ、玉ねぎを入れて中火で炒める。 全体にツナの油が馴染んだら☆を加えて混ぜる。 3が煮立ったら2分加熱して溶き卵をまわし入れる。 4の卵が固まってきたら火を止めてふたをし、半熟状になるまで余熱で火を通す。 器に盛り、かいわれをのせる。',
#   'servings': '1人分',
#   'category': '丼その他の丼よく使う野菜玉ねぎ',
#   'prep_time': '',
#   'cook_time': ''},
#  {'name': '簡単！香ばしい♪ ちくわとこんにゃくのピリ辛煮',
#   'total_time': '900',
#   'ingredients': 'ちくわ 2本 こんにゃく 1/2枚 ごま油 大さじ1 みりん 大さじ1 酒 大さじ1 砂糖 小さじ2 和風顆粒だし 小さじ1/2 しょうゆ 大さじ1 輪切り唐辛子 ひとつまみ',
#   'instructions': 'ちくわは1cmの輪切りにし、こんにゃくはスプーンを使い一口大に切る。 鍋に水とこんにゃくを入れ火にかけ、沸騰して2分程茹でたら水を切る。 鍋にごま油を入れて、ちくわ、こんにゃくを加え中火で全体に油がまわるまで炒める。 ☆の調味料を加えて一度混ぜたら、中火で2分ほど照りが出るまで煮る。',
#   'servings': '2人分',
#   'category': '煮物(魚介)煮魚こんにゃく',
#   'prep_time': '',
#   'cook_time': ''},
#  {'name': 'レンジでパパッと！ マグカップ朝食',
#   'total_time': '600',
#   'ingredients': '白ごはん マグカップ1杯(140g) 卵 1個 ベーコン 2枚 粉チーズ 大さじ2 牛乳 50cc 塩こしょう 少々 マカロニ(早ゆでタイプ) 20g ツナ缶(オイル煮) 1缶(70g) ブロッコリー(冷凍) 2個 トマトジュース 200cc 塩こしょう 少々 食パン(8枚切り) 1枚 ソーセージ 1本 ミニトマト 3個 コーン缶 大さじ1 卵 1個 塩こしょう 少々 牛乳 100cc',
#   'instructions': '〈カルボナーラリゾットを作る。〉マグカップに白ごはん、卵、粉チーズ、牛乳、塩こしょうを入れ、混ぜる。 ベーコンはキッチンバサミなどで1cm幅に切って加え、混ぜる。 ふんわりとラップをし、600Wのレンジで2分加熱して混ぜ合わせて完成。 〈ツナトマトのスープパスタを作る。〉ツナ缶は缶汁を切る。マグカップに材料を全て入れて混ぜる。 ふんわりとラップをし、600Wのレンジで4分加熱する。そのままマカロニが戻るまで2〜3分置いておく。 〈パンキッシュを作る。〉マグカップに卵、塩こしょう、牛乳を入れて混ぜる。 食パンをちぎり入れる。ソーセージをキッチンバサミで輪切りにして加え、ミニトマト、コーンを加える。 ふんわりとラップをし、600Wのレンジで3分、卵が固まるまで加熱して完成。',
#   'servings': '1人分',
#   'category': '各国のお米料理リゾット加工肉ベーコン',
#   'prep_time': '',
#   'cook_time': ''},
#  {'name': 'レンジでボウル一つでできる！ カルボナーラ風釜玉うどん',
#   'total_time': '900',
#   'ingredients': '冷凍うどん 1玉 ベーコン 2枚 卵黄 1個 粉チーズ 大さじ2 めんつゆ(3倍濃縮) 小さじ2 マヨネーズ 大さじ1 こしょう 適量',
#   'instructions': 'ベーコンは1cm幅に切る。\n耐熱容器にうどん、ベーコンを入れて、ラップをして600Wのレンジで表記時間通り加熱する。 容器にマヨネーズ、めんつゆを入れて混ぜる。加熱したうどん、ベーコンに加えて混ぜる 器にうどん、たれを入れて混ぜ、ベーコン、粉チーズ、こしょうをかける。最後に卵をのせる。',
#   'servings': '1人前',
#   'category': 'うどんあたたかいうどん釜玉うどん加工肉',
#   'prep_time': '',
#   'cook_time': ''},
#  {'name': 'レンジで作る！ マグカップオムライス',
#   'total_time': '600',
#   'ingredients': 'ごはん お茶碗1杯(150g) 卵 1個 ツナ缶[オイル漬け] 1缶(60g) マヨネーズ 大さじ1/2 ケチャップ 大さじ1 ケチャップ 適量 パセリ(刻み) 適量',
#   'instructions': 'ボウルに卵、マヨネーズを入れて混ぜる(卵液)。 マグカップにごはん、ツナ、ケチャップ(大さじ1)を入れてよく混ぜ、平らにならす(ケチャップライス)。 ケチャップライスの上に卵液を流し入れる。ふんわりとラップをし、600Wのレンジで2分加熱する。ケチャップ、パセリをかける。',
#   'servings': '1人分',
#   'category': 'オムライスその他のオムライス',
#   'prep_time': '',
#   'cook_time': ''},
#  {'name': '煮込まず絶品！ レンジ肉じゃが',
#   'total_time': '2400',
#   'ingredients': '豚こま切れ肉 150g じゃがいも 2個(300g) 玉ねぎ 1/2個(100g) にんじん 1/2本(75g) 酒 大さじ2 みりん 大さじ1 しょうゆ 大さじ2 砂糖 大さじ1',
#   'instructions': '玉ねぎは薄切りにする。じゃがいもは一口大に切る。にんじんは端から斜めに包丁を入れて、まわしながら小さめの一口大に切る。 耐熱容器に☆を入れて混ぜ、豚肉、玉ねぎ、じゃがいも、にんじんを加えて調味料がからむようによく混ぜる。 ふんわりとラップをして600Wのレンジで10分加熱し、全体をよく混ぜる。ラップをかけて、15分ほど粗熱がとれるまでおく。',
#   'servings': '2人分',
#   'category': '煮物(野菜)肉じゃが豚肉豚こま切れ肉',
#   'prep_time': '',
#   'cook_time': ''},
#  {'name': '簡単おつまみ！ チーズちくわの甘辛焼き',
#   'total_time': '300',
#   'ingredients': 'ちくわ 4本 プロセスチーズ 4個 サラダ油 大さじ1/2 白いりごま ひとつまみ 酒 小さじ1 みりん 小さじ2 しょうゆ 小さじ2 砂糖 ひとつまみ',
#   'instructions': 'ちくわは長さを半分に切る。プロセスチーズは1cm角の短い棒状に切る。 ちくわの穴にプロセスチーズを等分に詰め、同様に計8個作る。 フライパンにサラダ油を入れて熱し、2を入れて焼き色がつくまで中火で炒める。 ☆を加え、ちくわを転がしながら煮からめる。 白いりごまをちらして混ぜる。',
#   'servings': '2人分',
#   'category': 'その他の肉料理チーズ',
#   'prep_time': '',
#   'cook_time': ''},
#  {'name': '15分でできる！ 豚バラ肉のみそ漬け焼き',
#   'total_time': '900',
#   'ingredients': '豚バラ薄切り肉 200g ししとう 6本 サラダ油 大さじ1/2 酒 大さじ1 みりん 小さじ1 砂糖 小さじ1 みそ 大さじ2 おろしにんにく 小さじ1',
#   'instructions': '豚バラ薄切り肉は食べやすい大きさに切る。 保存袋に豚肉、☆を入れてもみこみ、冷蔵庫で10分程度つける。 フライパンにサラダ油を入れて中火で熱し、ししとうを入れてさっと炒めて取り出す。 同じフライパンを再び中火で熱し、豚肉を入れて、全体に焼き色がつくまでを炒める。器に盛り、ししとうを添える。',
#   'servings': '2人分',
#   'category': 'その他の肉料理夏の旬野菜ししとう豚肉',
#   'prep_time': '',
#   'cook_time': ''},
#  {'name': 'フライパンで簡単！ ひき肉チャプチェ',
#   'total_time': '900',
#   'ingredients': '豚ひき肉 100g 春雨 50g にんじん 1/3本(50g) ピーマン 2個 おろしにんにく 小さじ1/2 ごま油 大さじ1 白いりごま 適量 焼肉のたれ 大さじ2 酒 大さじ1 しょうゆ 小さじ2 ラー油 小さじ1/2 水 150cc',
#   'instructions': 'にんじんは千切りにする。ピーマンはへたと種を取り、千切りにする。 ボウルに☆を入れて混ぜる。 フライパンに半量のごま油(大さじ1/2)を入れて熱し、おろしにんにく、豚ひき肉を入れて中火で炒める。 肉の色が変わったらにんじん、ピーマンを加えてさっと炒め、☆を加えて煮立たせる。 春雨を加えて混ぜ、やわらかくなるまで3〜4分煮て、水分をとばす。残りのごま油(大さじ1/2)を加えて混ぜる。器に盛り、白いりごまをちらす。',
#   'servings': '2人分',
#   'category': '炒め物(野菜)チャプチェ豚肉豚ひき肉',
#   'prep_time': '',
#   'cook_time': ''},
#  {'name': 'ふわふわ♪さっぱり！ 豆腐の和風ハンバーグ',
#   'total_time': '1800',
#   'ingredients': '豚ひき肉 150g 木綿豆腐 1/2丁(150g) 玉ねぎ 1/2個(100g) 大葉 6枚 片栗粉 大さじ1 しょうゆ 小さじ1/2 おろしにんにく 小さじ1/3 酒 大さじ1 砂糖 小さじ1/2 めんつゆ[3倍濃縮] 大さじ2 おろししょうが 少々 サラダ油 大さじ1 大根おろし 適量',
#   'instructions': '木綿豆腐はキッチンペーパーを2枚重ねて包み、耐熱皿に入れて600Wのレンジで1分30秒加熱し、水気を切る。 玉ねぎはみじん切りにし、耐熱容器に入れてふんわりとラップをし、600Wのレンジで1分加熱し、粗熱をとる。 大葉は軸を取り、2枚は飾り用にとっておき、残りは千切りにする。 ボウルに豚ひき肉、豆腐、玉ねぎ、千切りにした大葉、☆を入れて粘りが出るまでよく混ぜ、2等分にして楕円形に成形する。 フライパンにサラダ油を入れて熱し、4のタネを入れて中火で焼き、焼き色がついたら裏に返してふたをして3〜4分、中まで火が通るまで蒸し焼きにする。 フライパンの表面をキッチンペーパーで拭きとり、★を入れて混ぜながら中火で煮詰める(和風ソース)。 ハンバーグを器に盛り、大葉(飾り用)をのせ、大根おろしをのせて和風ソースをかける。',
#   'servings': '2人分',
#   'category': '焼き物(肉)ハンバーグ豚肉豚ひき肉',
#   'prep_time': '',
#   'cook_time': ''},
#  {'name': 'レンジで時短おつまみ！ ささみとキャベツのあっさりネギ和え',
#   'total_time': '900',
#   'ingredients': 'ささみ 2本 キャベツ 1/8個 ねぎ 1/2本 酒 大さじ1 ポン酢しょうゆ 大さじ2',
#   'instructions': 'キャベツは千切りにする。ねぎはみじん切りにする。 耐熱皿にキャベツを広げ、ささみをおき、酒をふってふんわりとラップをし、600Wのレンジで肉に火が通るまで3分加熱する。取り出してそのまま粗熱をとる。 ボウルにねぎ、ポン酢しょうゆを入れて混ぜる(ねぎポン酢しょうゆだれ)。 ささみは粗熱がとれたら、手でさく。器にキャベツ、ささみを盛り、ねぎポン酢しょうゆだれをかける。',
#   'servings': '2人分',
#   'category': 'その他の肉料理よく使う野菜キャベツ秋冬の旬野菜',
#   'prep_time': '',
#   'cook_time': ''},
#  {'name': '10分簡単メニュー♪ キャベツとベーコンのスープ',
#   'total_time': '600',
#   'ingredients': 'ベーコン 4枚 キャベツ 葉2枚 水 600cc コンソメ 小さじ2 塩こしょう 適量',
#   'instructions': 'キャベツは食べやすい大きさに切る。ベーコンは1cm幅に切る。 鍋に水、コンソメ、ベーコン、キャベツを入れて中火で5分加熱し、塩こしょうで味をととのえる。',
#   'servings': '2人分',
#   'category': 'その他のスープよく使う野菜キャベツ加工肉',
#   'prep_time': '',
#   'cook_time': ''},
#  {'name': '材料はたった２つ！ 至高の濃厚プリン',
#   'total_time': '5400',
#   'ingredients': '卵 1個 アイス 1カップ(200g)',
#   'instructions': '耐熱容器にアイスを入れて600Wのレンジで1分加熱して溶かす。 ボウルに1を入れ、卵を割入れて混ぜる。耐熱容器に等分にこしながら入れ、同様に計2個作る。ラップをせずに600Wのレンジで1分30秒加熱する。粗熱をとる。 冷蔵庫で1時間以上冷やし固める。',
#   'servings': '2人前',
#   'category': '冷たいお菓子プリン',
#   'prep_time': '',
#   'cook_time': ''},
#  {'name': '和えるだけの激ウマおかず！ 無限豆苗',
#   'total_time': '300',
#   'ingredients': '豆苗 1パック ツナ 1缶(70g) 昆布茶 小さじ1 マヨネーズ 小さじ2 ごま油 小さじ1 こしょう 少々 すりごま 適量',
#   'instructions': '豆苗は根元を切り落として食べやすい大きさに切り、軽く洗って水気を切っておく ボウルに昆布茶、マヨネーズ、ごま油、こしょうを入れて混ぜる 豆苗、ツナを汁ごと加えて混ぜる すりごまをかけて完成',
#   'servings': '2人前',
#   'category': 'その他の野菜料理その他の野菜よく使う野菜豆苗',
#   'prep_time': '',
#   'cook_time': ''},
#  {'name': 'レンジで簡単おかず！ 蒸し鶏のやみつきえのきダレ',
#   'total_time': '1200',
#   'ingredients': '鶏むね肉 1枚(250g) えのき 1/4パック 長ねぎ 1本 塩 小さじ1/2 酒 小さじ1 細ねぎ(刻み) 適量 にんにく 1かけ しょうが 1かけ しょうゆ 大さじ2 鶏ガラスープの素 ひとつまみ ごま油 小さじ2',
#   'instructions': 'えのきは石づきを切り落とし、長さを半分に切る。 ねぎは斜め薄切りにする。しょうが、にんにくはみじん切りにする。 ボウルに☆を入れてよく混ぜる(やみつきだれ)。 大きめの耐熱容器に鶏肉を入れて塩、酒をふりかけてよく揉み込む。 4にえのき、ねぎをのせてやみつきだれを回しかける。 ふんわりとラップをかけて600Wのレンジで5分半〜6分加熱し、取り出してそのまま5分ほど置き、余熱で火を通す。 鶏肉を食べやすい大きさに切って器に盛り、えのき、ねぎ、容器に残ったたれをかけて細ねぎをちらす。',
#   'servings': '2人分',
#   'category': 'その他の肉料理よく使う野菜きのこ鶏肉',
#   'prep_time': '',
#   'cook_time': ''},
#  {'name': '濃厚クリーミー♡ えびのトマトクリームパスタ',
#   'total_time': '1800',
#   'ingredients': 'スパゲティ 200g 無頭えび 100g 玉ねぎ 1/2個 にんにく 1かけ オリーブオイル 大さじ1 カットトマト缶 1/2缶(200g) 牛乳 100cc コンソメ 小さじ1 塩 小さじ1/2 黒こしょう 適量',
#   'instructions': '玉ねぎは薄切りにする。にんにくはみじん切りにする。 えびは殻をむき、尾と背わたを取る。洗って水気をふきとる。 鍋に湯をわかし、スパゲティを入れて袋の表記時間通りにゆで、水気を切る。 フライパンにオリーブオイル、にんにくを入れて弱火で熱し、香りが立ったら玉ねぎを加えて中火でしんなりするまで炒める。 ☆を加えてさっと混ぜ、えびを加えてひと煮立ちさせる。 スパゲティを加えて混ぜ合わせる。',
#   'servings': '2人分',
#   'category': 'パスタクリームソースパスタえび',
#   'prep_time': '',
#   'cook_time': ''},
#  {'name': 'レンジでやみつき！ かんたん無限きのこ',
#   'total_time': '600',
#   'ingredients': 'ツナ缶[オイル漬け] 1缶(70g) しめじ 1/2パック(50g) まいたけ 1/2パック(50g) エリンギ 1本(40g) めんつゆ[3倍濃縮] 大さじ1 おろしにんにく 少々 鶏ガラスープの素 小さじ1/2 ごま油 小さじ1 こしょう 少々',
#   'instructions': 'しめじは根元を切り落とし、手でほぐす。まいたけは食べやすい大きさにほぐす。エリンギは食べやすい大きさに切る。 大きめの耐熱容器にめんつゆ、おろしにんにく、鶏ガラスープの素、ごま油を入れて混ぜる。1、ツナ缶を加えて混ぜ、ふんわりとラップをして600Wのレンジで1分30秒加熱する。 一度取り出して混ぜ、再度ふんわりとラップをして600Wのレンジで2分30秒加熱する。こしょうをふり、よく混ぜる。',
#   'servings': '3人分',
#   'category': 'その他の野菜料理ツナ缶よく使う野菜きのこ',
#   'prep_time': '',
#   'cook_time': ''},
#  {'name': '大さじ2の油で！ ちくわの磯辺揚げ',
#   'total_time': '600',
#   'ingredients': 'ちくわ 3本 サラダ油 大さじ2 薄力粉 大さじ1 片栗粉 大さじ1 水 大さじ1〜大さじ1と1/2 青のり 小さじ1 塩 少々',
#   'instructions': 'ちくわは斜め半分に切る。 ボウルに☆を入れて混ぜ、ちくわを加えてからめる。 フライパンにサラダ油を入れて熱し、2を入れて上下を返しながらこんがりと揚げ焼きにする。',
#   'servings': '2人分',
#   'category': 'その他の魚料理',
#   'prep_time': '',
#   'cook_time': ''},
#  {'name': 'くるくる巻いてチンするだけ！ ベーコン大葉チーズ巻き',
#   'total_time': '600',
#   'ingredients': 'ベーコン 4枚 大葉 4枚 プロセスチーズ 2枚 塩こしょう 少々',
#   'instructions': 'プロセスチーズは半分に切る。ベーコンに塩こしょうをふり、大葉、プロセスチーズをのせくるくると巻き、つまようじで止める。 耐熱容器にのせて、ふんわりとラップをして600Wのレンジで1分程度加熱する。',
#   'servings': '2人分',
#   'category': 'その他の肉料理加工肉ベーコンチーズ',
#   'prep_time': '',
#   'cook_time': ''},
#  {'name': 'レンジで本格！ 麻婆キャベツ丼',
#   'total_time': '600',
#   'ingredients': 'ごはん どんぶり2杯(400g) 豚ひき肉 100g キャベツ 1/6個 片栗粉 小さじ1 おろししょうが 小さじ1/2 砂糖 小さじ2 しょうゆ 大さじ1と1/2 鶏ガラスープの素 小さじ1 豆板醤 小さじ1/2 ごま油 大さじ1',
#   'instructions': 'キャベツはざく切りにする。 耐熱容器に☆を入れてよく混ぜ、豚ひき肉を加えてさらによく混ぜる。 ふんわりとラップをし、600Wのレンジで肉に火が通るまで3分加熱する。 取り出して片栗粉を加えて混ぜ、キャベツを加えてさらに混ぜる。ふんわりとラップをし、600Wのレンジでさらに2分加熱する。 器にごはんを盛り、4をのせる。',
#   'servings': '2人分',
#   'category': '丼その他の丼よく使う野菜キャベツ',
#   'prep_time': '',
#   'cook_time': ''},
#  {'name': '簡単10分主菜！ キャベツと鶏肉のオイマヨ炒め',
#   'total_time': '600',
#   'ingredients': 'キャベツ 4枚(160g) 鶏もも肉 1枚(200g) 片栗粉 大さじ1 サラダ油 大さじ1 オイスターソース 大さじ1と1/2 マヨネーズ 大さじ2 塩こしょう 適量',
#   'instructions': 'キャベツは食べやすい大きさに切る。 鶏もも肉は一口大に切り、片栗粉をまぶす。 フライパンにサラダ油を入れて熱し、鶏肉を入れて中火で肉の色が変わるまで炒める。キャベツを加えて2～3分炒める。 3にオイスターソース、マヨネーズを加えて混ぜ、塩こしょうを加えて味をととのえる。',
#   'servings': '2人分',
#   'category': '炒め物(野菜)野菜炒め鶏肉鶏もも肉',
#   'prep_time': '',
#   'cook_time': ''},
#  {'name': '器に入れてレンジでチン♪ 包まない小籠包',
#   'total_time': '1800',
#   'ingredients': '餃子の皮 8枚 鶏ガラスープの素 大さじ1/2 粉ゼラチン 5g 湯 100cc 豚ひき肉 150g 細ねぎ 2本 酒 小さじ1 塩こしょう 少々 しょうゆ 小さじ1 オイスターソース 小さじ1 おろししょうが 小さじ1/2 おろしにんにく 小さじ1/2 ごま油 小さじ1',
#   'instructions': 'ボウルに鶏ガラスープの素、粉ゼラチン、湯を入れて混ぜ、冷蔵庫で冷やし固める 細ねぎは小口切りにする ボウルに☆を入れて粘りが出るまでよくこねる 1を崩しながら入れ、混ぜ合わせる 2つの耐熱容器に半量ずつ肉だねを入れ、餃子の皮を各4枚水にくぐらせてのせ、ふんわりとラップをして600Wのレンジで1分30秒、スープがふつふつするまで加熱する。',
#   'servings': '2人分',
#   'category': '小籠包豚肉',
#   'prep_time': '',
#   'cook_time': ''},
#  {'name': '炊飯器でほったらかし！ ほろほろチキンのトマト煮',
#   'total_time': '3600',
#   'ingredients': '鶏もも肉 2枚(500g) 玉ねぎ 1個(200g) エリンギ 1本(50g) にんじん 1本(150g) カットトマト缶 1缶(400g) 酒 大さじ1 酢 大さじ1 砂糖 小さじ1 塩 小さじ1/2 こしょう 少々 オリーブオイル 大さじ2 コンソメ 小さじ2 水 100cc',
#   'instructions': '鶏もも肉は皮目にフォークで穴を開け、十字に4等分に切る。 玉ねぎは縦半分に切って切り口を下にし、繊維を断ち切るように1cm幅に切る。 エリンギは縦半分に切り、切り口を下にして横1cm幅に切る。 にんじんは根元を切り落とし、斜めに包丁を入れてまわしながら大きめの一口大に切る。 炊飯器の内釜に☆を入れて混ぜる。鶏もも肉、にんじん、玉ねぎ、エリンギを加えて具材をひたし、通常炊飯する。',
#   'servings': '4人分(5.5合炊き炊飯器使用)',
#   'category': 'その他の肉料理夏の旬野菜トマト鶏肉',
#   'prep_time': '',
#   'cook_time': ''},
#  {'name': '10分でパパッと副菜！ 無限キャベツ',
#   'total_time': '600',
#   'ingredients': 'ツナ 1缶(70g) キャベツ 1/4個 鶏がらスープの素 小さじ1 マヨネーズ 小さじ1 ごま油 小さじ1 こしょう 少々',
#   'instructions': 'キャベツは千切りにして耐熱容器に入れる。 1にツナ、鶏ガラスープの素、マヨネーズ、ごま油を加えてよく混ぜる。 ふんわりとラップをし、600Wのレンジで2分加熱する。 全体をなじませるように混ぜ合わせる。器に盛り、こしょうをふる。',
#   'servings': '2人分',
#   'category': 'その他の野菜料理ツナ缶よく使う野菜キャベツ',
#   'prep_time': '',
#   'cook_time': ''}]

# %%
print(result_list)
# Out:
# [{'name': 'レンジでできる！ 豚バラもやしのバターポン酢', 'total_time': '600', 'ingredients': '豚バラ薄切り肉 150g もやし 1袋(200g) 酒 大さじ1 有塩バター 大さじ1 ポン酢しょうゆ 大さじ2 かつお節 1パック 七味唐辛子 適量 細ねぎ（刻み） 適量', 'instructions': '豚肉は食べやすい大きさに切る。耐熱容器にもやしを入れ、かつお節を振り入れ、その上に切った豚肉を広げてのせる 酒を全体に振りかけてバターをところどころに乗せ、ふんわりラップをして600Wのレンジで5～6分加熱する。 豚肉に火が通ったらポン酢しょうゆを全体を混ぜる。器に盛り、七味唐辛子をふって刻んだ細ねぎを乗せて完成！', 'servings': '2人分', 'category': 'その他の野菜料理豚肉豚バラ薄切り肉よく使う野菜', 'prep_time': '', 'cook_time': ''}, {'name': '甘い味噌味が食欲そそる！ 豚じゃが味噌炒め', 'total_time': '900', 'ingredients': 'じゃがいも 1個 豚こま切れ肉 70g ごま油 大さじ1/2 ネギ 適量 白ごま 適量 酒 小さじ1 片栗粉 小さじ1 味噌 小さじ1 酒 小さじ1 砂糖 小さじ2 みりん 小さじ1', 'instructions': '皮ごとよく洗ったじゃがいもを500wのレンジで5分加熱する \n粗熱が取れたら一口大に切る 豚肉に酒、片栗粉を揉み込む フライパンにごま油を熱し、肉を焼いていく \n焼き色がついてきたらじゃがいもを加える 味噌、砂糖、酒、みりんをよく混ぜて加え、全体にからませる \n仕上げにネギ、ごまを散らして完成！', 'servings': '1人分', 'category': '煮物(野菜)肉じゃが秋冬の旬野菜ねぎ', 'prep_time': '', 'cook_time': ''}, {'name': '時短がっつりおかず！ チーズ焼き卵巾着', 'total_time': '900', 'ingredients': '油揚げ 1枚 卵 2個 スライスチーズ 1枚 サラダ油 小さじ2 酒 大さじ1 みりん 大さじ2 しょうゆ 大さじ2 砂糖 大さじ1', 'instructions': '油揚げを半分に切り、袋状に開いて内側をひっくり返す。 1に半分に切って小さく折りたたんだスライスチーズを入れ、卵を1個ずつ割り入れる。つまようじで口をとめる。 フライパンにサラダ油を入れて熱し、2を並べる。弱火で5分程度焼いたらひっくり返し、もう片面も同様に焼く。 3に☆を加えて煮からめる。', 'servings': '2人分', 'category': 'その他の卵料理豆類大豆加工品油揚げ', 'prep_time': '', 'cook_time': ''}, {'name': '定番の一品！ ほうれん草のごま和え', 'total_time': '300', 'ingredients': 'ほうれん草 1袋(200g) 白すりごま 大さじ3 砂糖 小さじ2 しょうゆ 小さじ2 和風顆粒だし 小さじ1', 'instructions': 'ほうれん草は洗い、ラップにしっかりと包んで600Wのレンジで1分30秒〜40秒程加熱し、水にさらしておく。 水気を切ったほうれん草の根元を切り落とし、食べやすい大きさに切る。 ボウルに白すりごま、☆を入れて混ぜ、ほうれん草を加えてあえる。', 'servings': '2人前', 'category': '蒸し物・お浸し(野菜)お浸し秋冬の旬野菜ほうれん草', 'prep_time': '', 'cook_time': ''}, {'name': '丸めず簡単！ レンチン豆腐ハンバーグ', 'total_time': '900', 'ingredients': '合挽き肉 100g 絹豆腐 150g コンソメ 小さじ1 ケチャップ 大さじ1 中濃ソース 大さじ1 サラダ油 小さじ1 塩こしょう 少々 ピザ用チーズ 適量 卵 1個 パセリ[乾燥] 少々', 'instructions': 'ボウルに豆腐、合びき肉、コンソメ、ケチャップ、ソース、サラダ油、塩こしょうを加えて混ぜる。耐熱皿に入れてならし、ピザ用チーズをちらす。 ラップをせずに、600Wのレンジで7〜8分加熱する。 中央に温泉卵をのせて、パセリをちらす。', 'servings': '2人分', 'category': '焼き物(肉)ハンバーグ豆類大豆加工品', 'prep_time': '', 'cook_time': ''}, {'name': '味付けバッチリ！ なすとひき肉の甘辛炒め', 'total_time': '600', 'ingredients': 'なす 3本 鶏ひき肉 150g 細ねぎ（刻み） 適量 サラダ油(なす用) 大さじ3 サラダ油(肉用) 小さじ1 酒 大さじ1 砂糖 小さじ1 しょうゆ 大さじ1 みりん 大さじ1', 'instructions': 'なすは食べやすい大きさに切る。フライパンにサラダ油を熱し、なすを入れ柔らかくなるまで中火で炒め、取り出す。 フライパンにサラダ油を入れて熱し鶏ひき肉を入れて中火で炒め、肉の色が変わったらなすを戻す。 ☆の調味料を加えて炒め合わせる。器に盛り付けて、細ねぎを散らして完成。', 'servings': '2人分', 'category': '炒め物(野菜)その他の炒め物（野菜）夏の旬野菜なす', 'prep_time': '', 'cook_time': ''}, {'name': 'パパッと簡単絶品♪ ツナ玉ねぎの卵とじ丼', 'total_time': '600', 'ingredients': 'ごはん どんぶり1杯(200g) ツナ缶[オイル漬け] 1缶(70g) 溶き卵 2個分 玉ねぎ 1/2個 かいわれ 適量 水 100cc しょうゆ 小さじ4 和風顆粒だし ひとつまみ', 'instructions': '玉ねぎは薄切りにする。 フライパンにツナ缶を缶汁ごと入れ、玉ねぎを入れて中火で炒める。 全体にツナの油が馴染んだら☆を加えて混ぜる。 3が煮立ったら2分加熱して溶き卵をまわし入れる。 4の卵が固まってきたら火を止めてふたをし、半熟状になるまで余熱で火を通す。 器に盛り、かいわれをのせる。', 'servings': '1人分', 'category': '丼その他の丼よく使う野菜玉ねぎ', 'prep_time': '', 'cook_time': ''}, {'name': '簡単！香ばしい♪ ちくわとこんにゃくのピリ辛煮', 'total_time': '900', 'ingredients': 'ちくわ 2本 こんにゃく 1/2枚 ごま油 大さじ1 みりん 大さじ1 酒 大さじ1 砂糖 小さじ2 和風顆粒だし 小さじ1/2 しょうゆ 大さじ1 輪切り唐辛子 ひとつまみ', 'instructions': 'ちくわは1cmの輪切りにし、こんにゃくはスプーンを使い一口大に切る。 鍋に水とこんにゃくを入れ火にかけ、沸騰して2分程茹でたら水を切る。 鍋にごま油を入れて、ちくわ、こんにゃくを加え中火で全体に油がまわるまで炒める。 ☆の調味料を加えて一度混ぜたら、中火で2分ほど照りが出るまで煮る。', 'servings': '2人分', 'category': '煮物(魚介)煮魚こんにゃく', 'prep_time': '', 'cook_time': ''}, {'name': 'レンジでパパッと！ マグカップ朝食', 'total_time': '600', 'ingredients': '白ごはん マグカップ1杯(140g) 卵 1個 ベーコン 2枚 粉チーズ 大さじ2 牛乳 50cc 塩こしょう 少々 マカロニ(早ゆでタイプ) 20g ツナ缶(オイル煮) 1缶(70g) ブロッコリー(冷凍) 2個 トマトジュース 200cc 塩こしょう 少々 食パン(8枚切り) 1枚 ソーセージ 1本 ミニトマト 3個 コーン缶 大さじ1 卵 1個 塩こしょう 少々 牛乳 100cc', 'instructions': '〈カルボナーラリゾットを作る。〉マグカップに白ごはん、卵、粉チーズ、牛乳、塩こしょうを入れ、混ぜる。 ベーコンはキッチンバサミなどで1cm幅に切って加え、混ぜる。 ふんわりとラップをし、600Wのレンジで2分加熱して混ぜ合わせて完成。 〈ツナトマトのスープパスタを作る。〉ツナ缶は缶汁を切る。マグカップに材料を全て入れて混ぜる。 ふんわりとラップをし、600Wのレンジで4分加熱する。そのままマカロニが戻るまで2〜3分置いておく。 〈パンキッシュを作る。〉マグカップに卵、塩こしょう、牛乳を入れて混ぜる。 食パンをちぎり入れる。ソーセージをキッチンバサミで輪切りにして加え、ミニトマト、コーンを加える。 ふんわりとラップをし、600Wのレンジで3分、卵が固まるまで加熱して完成。', 'servings': '1人分', 'category': '各国のお米料理リゾット加工肉ベーコン', 'prep_time': '', 'cook_time': ''}, {'name': 'レンジでボウル一つでできる！ カルボナーラ風釜玉うどん', 'total_time': '900',  ...
