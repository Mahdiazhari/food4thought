# %%
import pandas as pd
import json
import requests
import random
from lxml import html
import re
import time

from  util.spider import Spider
from util.http_utility import get_http_headers
from util.user_agent import get_random_ua

# %% [markdown]
# # Scrape Japan - Delishtv

# %%
class DelishKitchen(Spider): #inherit Spider Class
    """This class extends the main Spider Class for Scraping Delish TV recipe website.

    Args:
        Spider (_type_): _description_
    """

    def __init__(self, main_page, seeds, listing, attrs, header=None):
        super().__init__(main_page,seeds,listing,attrs,header)

    def scrape_one_item(self,url):
        """To scrape one item from a given url.

        Args:
            url (str): url of the item

        Returns:
            dict: dict of the item
        """
        session = requests.Session() 
        session.headers.update(self.header)

        #add home page url to the obtained item url if item url is not complete
        if self.main_page not in url:
            res = session.get(self.main_page + url)
        else:
            res = session.get(url)

        if res.status_code == 200:
            try:
                #print(res.status_code)
                doc = html.document_fromstring(res.text)
                #set default values for variables
                name, total_time, ingredients, instructions, servings, category, prep_time, cook_time = '','','','','','','',''

                doc = html.document_fromstring(res.text)

                
                #get data from script application json with recipeIngredient
                script_data = json.loads(doc.xpath("normalize-space(//script[@type='application/ld+json'][contains(text(), 'recipeIngredient')])"))
                print(script_data)

                name = script_data.get('name')

                ingredients = script_data.get('recipeIngredients')
                ingredients = ' '.join(ingredients)# join ingredients

                instructions = []
                inst_list_web = script_data.get('recipeInstructions')

                for instruction in inst_list_web:
                    instructions.append(instruction['text'])
                instructions= ' '.join(instructions) #join all as one


                servings = script_data.get('recipeYield')

                category = 

            




                total_time = script_data.get('totalTime')
                cook_time = script_data.get('cookTime')
                prep_time = script_data.get('prepTime')

                # #Name
                # if self.check_normalize_space(self.attrs['name']):
                #     name = doc.xpath(self.attrs['name'])
                # else: name = doc.xpath(self.attrs['name'])[0]

                # #Total Time
                # if self.check_normalize_space(self.attrs['total_time']):
                #     total_time = doc.xpath(self.attrs['total_time'])
                # else:  total_time = doc.xpath(self.attrs['total_time'])[0]

                # #ingredients
                # ingredients = doc.xpath(self.attrs['ingredients'])
                # clean_ingredients = []
                # for ing in ingredients:
                #     ing = ing.replace('\t','')
                #     ing = ing.replace('\r','')
                #     ing = ing.replace('\n','')
                #     clean_ingredients.append(ing)
                # #print(clean_ingredients)
                # ingredients = ''.join(clean_ingredients)
                # ingredients = ingredients.strip()
                # # ingredient_str = ''
                # # for ing in ingredients:
                # #     if  ' ' not in str(ing):
                # #         ingredient_str += ing
                # # ingredients = ingredient_str
                

                # #instructions
                # instructions = doc.xpath(self.attrs['instructions'])
                # #print(instructions)
                # instructions= ''.join(instructions)
                
                # # instructions_str = ''
                # # for ins in instructions:
                # #     if  ' ' not in str(ins): 
                # #         instructions_str += ins
                # # instructions = instructions_str

                # # if self.check_normalize_space(self.attrs['instructions']):
                # #     instructions = doc.xpath(self.attrs['instructions'])
                # # else:  instructions = doc.xpath(self.attrs['instructions'])[0]

                # #servings
                # if self.attrs['servings']:
                #     if self.check_normalize_space(self.attrs['servings']):
                #         servings = doc.xpath(self.attrs['servings'])
                #     else: servings = doc.xpath(self.attrs['servings'])[0]

                # #category
                # if self.attrs['category']:
                #     if self.check_normalize_space(self.attrs['category']):
                #         category = doc.xpath(self.attrs['category'])
                #     else: category = doc.xpath(self.attrs['category'])[0]

                # #prep time
                # if self.attrs['prep_time']:
                #     if self.check_normalize_space(self.attrs['prep_time']):
                #         prep_time = doc.xpath(self.attrs['prep_time'])
                #     else: prep_time = doc.xpath(self.attrs['prep_time'])[0]
                
                # #cooking time
                # if self.attrs['cook_time']:
                #     if self.check_normalize_space(self.attrs['cook_time']):
                #         cook_time = doc.xpath(self.attrs['cook_time'])
                #     else: cook_time = doc.xpath(self.attrs['cook_time'])[0]
                
                return {'name': name, 'total_time': total_time, 'ingredients': ingredients, 'instructions': instructions, 'servings': servings,
                'category': category, 'prep_time': prep_time, 'cook_time': cook_time,}
            except Exception as e:
                raise Exception('something is wrong for item: {}'.format(url)) from e


        else:
            raise Exception('Cannot open one menu url, status code = {}'.format(res.status_code))

# %%
listing={'items': '//ul[@class="columns with-max-three"]//div[contains(@class,"delish-renewal-recipe-item-card")]//a/@href', 'next': { 'next_page_str': '?page={}', 'type': 'url'}}
seeds = ['https://delishkitchen.tv/categories/2937']

# %%
delishtv_spider= DelishKitchen('https://delishkitchen.tv/', seeds= seeds, listing =listing,attrs= '')

# %%
delishtv_spider.scrape_one_item('https://delishkitchen.tv/recipes/216142397518644383')
# Out:
# {'@context': 'http://schema.org', '@type': 'Recipe', 'name': '冷凍餃子を使ってお手軽に♪ ニラもやしの餃子鍋', 'description': 'にんにく、しょうがを効かせたスープがクセになる♪たっぷり野菜が食べられるのでお腹も満足♪パパッとできるのもおすすめです。', 'keywords': '鍋料理, その他の鍋料理', 'datePublished': '2018-10-01T02:21:48Z', 'dateModified': '2019-02-21T04:25:02Z', 'recipeYield': '2人分', 'recipeIngredient': ['冷凍餃子 12個', '豆もやし 1袋', 'ニラ 1/2束', 'しめじ 1パック', '酒 大さじ1', '塩 小さじ1/3', '鶏ガラスープの素 小さじ1/2', 'おろしにんにく 小さじ1', 'おろししょうが 小さじ1', '水 300cc', '唐辛子(輪切り) 少々', 'ポン酢しょうゆ 大さじ2', 'ラー油 適量'], 'recipeInstructions': [{'@type': 'HowToStep', 'text': 'ニラは3cm幅に切る。しめじは根元を切り落とし、小房に分ける。'}, {'@type': 'HowToStep', 'text': 'ボウルに豆もやし、ニラ、しめじを入れて混ぜる。'}, {'@type': 'HowToStep', 'text': '別のボウルに☆を入れて混ぜる(鍋スープ)。'}, {'@type': 'HowToStep', 'text': '鍋に半量の2を敷き詰め、餃子は鍋に沿うように並べ入れて、中央に残りの2をのせる。鍋スープをまわしかけ、中火に熱し、煮立ったらふたをして5分程煮る。'}, {'@type': 'HowToStep', 'text': '4にポン酢しょうゆ、ラー油を添える。'}], 'image': 'https://image.delishkitchen.tv/recipe/216142397518644383/1.jpg?version=1550723102', 'headline': '「冷凍餃子を使ってお手軽に♪ニラもやしの餃子鍋」をレシピ動画で！', 'nutrition': {'@type': 'NutritionInformation', 'calories': '329kcal'}, 'author': {'@type': 'Organization', 'name': 'DELISH KITCHEN', 'url': 'https://delishkitchen.tv/s/images/icon.png?version=20191025'}, 'publisher': {'@type': 'Organization', 'name': 'DELISH KITCHEN', 'url': 'https://delishkitchen.tv/s/images/icon.png?version=20191025'}, 'mainEntityOfPage': {'@type': 'WebPage', '@id': 'https://delishkitchen.tv/recipes/216142397518644383'}, 'cookTime': 'PT1200S', 'prepTime': 'PT0M', 'totalTime': 'PT1200S', 'video': {'@type': 'VideoObject', 'name': 'ニラもやしの餃子鍋', 'thumbnail': 'https://image.delishkitchen.tv/recipe/216142397518644383/1.jpg?version=1550723102', 'thumbnailUrl': 'https://image.delishkitchen.tv/recipe/216142397518644383/1.jpg?version=1550723102', 'contentUrl': 'https://media.delishkitchen.tv/recipe/216142397518644383/1.mp4', 'uploadDate': '2019-02-21T04:25:02Z', 'description': 'にんにく、しょうがを効かせたスープがクセになる♪たっぷり野菜が食べられるのでお腹も満足♪パパッとできるのもおすすめです。', 'author': {'@type': 'Organization', 'name': 'DELISH KITCHEN', 'url': 'https://delishkitchen.tv/s/images/icon.png?version=20191025'}}, 'aggregateRating': {'@type': 'AggregateRating', 'ratingValue': '4.3', 'reviewCount': 31, 'bestRating': 5, 'worstRating': 1}, 'review': [{'@type': 'Review', 'author': {'@type': 'Person', 'name': 'じゅうえん'}, 'datePublished': '2021-12-12T23:59:10Z', 'reviewBody': '簡単で美味しいスープの味付けで、おいしいです。〆は中華麺をいれてみたら、美味しかったです。もやしとにらと人参がパックになってるのを使うと忙しい時、すぐに作れました。', 'reviewRating': {'@type': 'Rating', 'ratingValue': 5, 'bestRating': 5, 'worstRating': 1}}, {'@type': 'Review', 'author': {'@type': 'Person', 'name': 'ぴぴ'}, 'datePublished': '2020-07-20T12:18:55Z', 'reviewBody': '冷凍餃子ではなくて水餃子で作ってみました！\nもちもちで美味しかったです👌\n残り物の野菜もたくさん入れてみました😎✔️', 'reviewRating': {'@type': 'Rating', 'ratingValue': 5, 'bestRating': 5, 'worstRating': 1}}, {'@type': 'Review', 'author': {'@type': 'Person', 'name': 'リヒョナ'}, 'datePublished': '2020-10-01T01:26:27Z', 'reviewBody': '簡単に出来ました。\n美味しかったです。', 'reviewRating': {'@type': 'Rating', 'ratingValue': 4, 'bestRating': 5, 'worstRating': 1}}, {'@type': 'Review', 'author': {'@type': 'Person', 'name': 'ちぴ'}, 'datePublished': '2021-10-23T10:35:37Z', 'reviewBody': 'おいしかったです。', 'reviewRating': {'@type': 'Rating', 'ratingValue': 4, 'bestRating': 5, 'worstRating': 1}}, {'@type': 'Review', 'author': {'@type': 'Person', 'name': 'お昼寝を邪魔する小鳥'}, 'datePublished': '2021-12-16T10:59:06Z', 'reviewBody': '簡単で美味しかったけど、ニラとニンニクで臭う臭う…。\n人に会う予定がある直前はやめた方がいいです。\nそれとお腹が次の日痛くなりました。', 'reviewRating': {'@type': 'Rating', 'ratingValue': 3, 'bestRating': 5, 'worstRating': 1}}, {'@type': 'Review', 'author': {'@type': 'Person', 'name': 'ゆり'}, 'datePublished': '2020-10-28T14:00:21Z', 'reviewBody': '２倍量で作りましたが簡単に美味しく出来ました！', 'reviewRating': {'@type': 'Rating', 'ratingValue': 5, 'bestRating': 5, 'worstRating': 1}}, {'@type': 'Review', 'author': {'@type': 'Person', 'name': 'スカイまま'}, 'datePublished': '2020-12-03T05:18:38Z', 'reviewBody': 'ほんとに、簡単。\nあっという間に出来て美味しい。\n絶対におすすめです。', 'reviewRating': {'@type': 'Rating', ...
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /Users/mahdiazhari/world-bank/japan-delishtv.ipynb Cell 4' in DelishKitchen.scrape_one_item(self, url)
#      <a href='vscode-notebook-cell:/Users/mahdiazhari/world-bank/japan-delishtv.ipynb#ch0000003?line=42'>43</a> #Name
# ---> <a href='vscode-notebook-cell:/Users/mahdiazhari/world-bank/japan-delishtv.ipynb#ch0000003?line=43'>44</a> if self.check_normalize_space(self.attrs['name']):
#      <a href='vscode-notebook-cell:/Users/mahdiazhari/world-bank/japan-delishtv.ipynb#ch0000003?line=44'>45</a>     name = doc.xpath(self.attrs['name'])
#
# TypeError: string indices must be integers
#
# The above exception was the direct cause of the following exception:
#
# Exception                                 Traceback (most recent call last)
# /Users/mahdiazhari/world-bank/japan-delishtv.ipynb Cell 7' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/mahdiazhari/world-bank/japan-delishtv.ipynb#ch0000006?line=0'>1</a> delishtv_spider.scrape_one_item('https://delishkitchen.tv/recipes/216142397518644383')
#
# /Users/mahdiazhari/world-bank/japan-delishtv.ipynb Cell 4' in DelishKitchen.scrape_one_item(self, url)
#     <a href='vscode-notebook-cell:/Users/mahdiazhari/world-bank/japan-delishtv.ipynb#ch0000003?line=109'>110</a>         return {'name': name, 'total_time': total_time, 'ingredients': ingredients, 'instructions': instructions, 'servings': servings,
#     <a href='vscode-notebook-cell:/Users/mahdiazhari/world-bank/japan-delishtv.ipynb#ch0000003?line=110'>111</a>         'category': category, 'prep_time': prep_time, 'cook_time': cook_time,}
#     <a href='vscode-notebook-cell:/Users/mahdiazhari/world-bank/japan-delishtv.ipynb#ch0000003?line=111'>112</a>     except Exception as e:
# --> <a href='vscode-notebook-cell:/Users/mahdiazhari/world-bank/japan-delishtv.ipynb#ch0000003?line=112'>113</a>         raise Exception('something is wrong for item: {}'.format(url)) from e
#     <a href='vscode-notebook-cell:/Users/mahdiazhari/world-bank/japan-delishtv.ipynb#ch0000003?line=115'>116</a> else:
#     <a href='vscode-notebook-cell:/Users/mahdiazhari/world-bank/japan-delishtv.ipynb#ch0000003?line=116'>117</a>     raise Exception('Cannot open one menu url, status code = {}'.format(res.status_code))
#
# Exception: something is wrong for item: https://delishkitchen.tv/recipes/216142397518644383
